# %% [markdown]
# Any cell that should be run everytime will have * in the top comment/line
#
# near future upgrades : buffered write to txt file (dont want to add delay if not needed
# how do you determine what the buffer size should be and what are the units ?
# move arduino to opposite side of the rig to enable camera placement on user side
# it actuaLLY matters if mouse is holding bar when behavior starts, so we need to start behvaior before the bar is placed
# otherwise the bar touch sensor will not work until it slowly recalibrates itself
#
# also i think we could make the lines specifically print around solenoid activated bc thats what i care about seeing real time (ie is it licking?)
#
# tomorrow morning work on the damn camera system with atlas

# %%
# * run at start of each session, clear all variables
for var in list(globals().keys()):
    if var not in ['__builtins__', '__name__', '__doc__', '__package__', '__loader__', '__spec__', '__annotations__']:
        del globals()[var]

# %%
import serial
import time 
from datetime import datetime
import os
import csv
import pandas as pd
from tkinter import Tk
from tkinter.filedialog import askdirectory

# %% [markdown]
# To get port number type 'ls /dev/tty.*' in terminal

# %% [markdown]
# Press esc M to change cell to text (markdown)
# To stop cell, click outside of code section and press II quickly (not capital)

# %%
# * run this cell to test behavior rig for run_time
port = '/dev/tty.usbmodem101'  # Replace with your Arduino's port
baudrate = 115200  # make sure this matches the baud rate in the Arduino sketch (.ino file)
run_time = 600 #sec
#request user for identiying information
animal_ID = input("Enter Animal ID: ")
training_stage = input("Enter training stage: ")

#open window to choose directory 
root = Tk()
root.withdraw()  # Hide the main tkinter window
save_directory = askdirectory(title="Select Directory to Save Data File")
data_filename = f"{animal_ID}_{training_stage}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
data_filepath = os.path.join(save_directory, data_filename)

#initialize file to write to as 'file'
with open(data_filepath, 'w') as file:
    #initialize serial connection
    ser = serial.Serial(port, baudrate, timeout=1)
    time.sleep(2) 
    
    #TRIGGER CAMERA, 2P HERE
    
    #send start command to Arduino
    start_time = time.time() #use for duration based arduino script start/stop
    ser.write(b'S') 
    behav_active = True
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
    print(f'{timestamp} - Sent start command to Arduino.')
    file.write(f'{timestamp} - Sent start command to Arduino.\n')
    
    try:
        count = 0
        # Read data from Arduino
        while behav_active:
            if ser.in_waiting > 0:
                try:
                    line = ser.readline().decode('utf-8', errors='ignore').rstrip()
                    timestamp = datetime.now().strftime('%H:%M:%S.%f')[:-3]
                    log_line = f'{timestamp} - Arduino: {line}\n'
                    # Reduce print statements to every 10th message
                    count += 1
                    if count % 10 == 0:
                        print(log_line, end='')
                    #print(log_line, end='')  # Print the data in real-time
                    file.write(log_line)  # Save data to file incrementally
                    file.flush()  # Ensure the data is written to the disk
                    os.fsync(file.fileno())  # Force writing to disk
                except UnicodeDecodeError:
                    print("Failed to decode serial data")
                    continue
    
            # Check if 20 seconds have passed to send the stop command
            if time.time() - start_time >= run_time:
                #execution line (send stop command to arduino)
                ser.write(b'X') 
                #reporting lines
                print('Sent stop command to Arduino.')
                timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
                file.write(f'{timestamp} - Sent stop command to Arduino.')
                #exit behavior code line
                behav_active = False
    
    except KeyboardInterrupt:
        #execution line (send stop command to arduino)
        ser.write(b'X')
        #reporting lines
        print("Interrupted by user. Sent stop command to Arduino.")
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
        file.write(f'{timestamp} - Interrupted by user. Sent stop command to Arduino.')
    finally:
        #close serial connection
        ser.close()
# Out:
# Enter Animal ID:  806N
# Enter training stage:  Lick
# 2024-08-15 00:11:25.761 - Sent start command to Arduino.
# 00:11:25.782 - Arduino: bar: 6
# 00:11:25.798 - Arduino: lick: 7
# 00:11:25.814 - Arduino: 0
# 00:11:25.835 - Arduino: bar: 6
# 00:11:25.851 - Arduino: lick: 8
# 00:11:25.868 - Arduino: 0
# 00:11:25.888 - Arduino: bar: 6
# 00:11:25.904 - Arduino: lick: 7
# 00:11:25.921 - Arduino: 0
# 00:11:25.941 - Arduino: bar: 7
# 00:11:25.958 - Arduino: lick: 6
# 00:11:25.974 - Arduino: 0
# 00:11:25.994 - Arduino: bar: 6
# 00:11:26.011 - Arduino: lick: 7
# 00:11:26.027 - Arduino: 0
# 00:11:26.048 - Arduino: bar: 6
# 00:11:26.064 - Arduino: lick: 8
# 00:11:26.081 - Arduino: 0
# 00:11:26.101 - Arduino: bar: 6
# 00:11:26.117 - Arduino: lick: 8
# 00:11:26.134 - Arduino: 0
# 00:11:26.154 - Arduino: bar: 6
# 00:11:26.171 - Arduino: lick: 7
# 00:11:26.187 - Arduino: 0
# 00:11:26.207 - Arduino: bar: 7
# 00:11:26.224 - Arduino: lick: 7
# 00:11:26.240 - Arduino: 0
# 00:11:26.261 - Arduino: bar: 6
# 00:11:26.277 - Arduino: lick: 8
# 00:11:26.294 - Arduino: 0
# 00:11:26.314 - Arduino: bar: 6
# 00:11:26.330 - Arduino: lick: 7
# 00:11:26.347 - Arduino: 0
# 00:11:26.367 - Arduino: bar: 7
# 00:11:26.384 - Arduino: lick: 8
# 00:11:26.400 - Arduino: 0
# 00:11:26.420 - Arduino: bar: 7
# 00:11:26.437 - Arduino: lick: 7
# 00:11:26.453 - Arduino: 0
# 00:11:26.474 - Arduino: bar: 6
# 00:11:26.490 - Arduino: lick: 7
# 00:11:26.507 - Arduino: 0
# 00:11:26.527 - Arduino: bar: 6
# 00:11:26.543 - Arduino: lick: 7
# 00:11:26.560 - Arduino: 0
# 00:11:26.580 - Arduino: bar: 6
# 00:11:26.596 - Arduino: lick: 7
# 00:11:26.613 - Arduino: 0
# 00:11:26.633 - Arduino: bar: 7
# 00:11:26.650 - Arduino: lick: 8
# 00:11:26.666 - Arduino: 0
# 00:11:26.687 - Arduino: bar: 6
# 00:11:26.703 - Arduino: lick: 7
# 00:11:26.720 - Arduino: 0
# 00:11:26.740 - Arduino: bar: 6
# 00:11:26.756 - Arduino: lick: 8
# 00:11:26.773 - Arduino: 0
# 00:11:26.793 - Arduino: bar: 6
# 00:11:26.810 - Arduino: lick: 7
# 00:11:26.826 - Arduino: 0
# 00:11:26.846 - Arduino: bar: 6
# 00:11:26.863 - Arduino: lick: 8
# 00:11:26.879 - Arduino: 0
# 00:11:26.899 - Arduino: bar: 8
# 00:11:26.916 - Arduino: lick: 7
# 00:11:26.932 - Arduino: 0
# 00:11:26.953 - Arduino: bar: 6
# 00:11:26.969 - Arduino: lick: 8
# 00:11:26.986 - Arduino: 0
# 00:11:27.006 - Arduino: bar: 6
# 00:11:27.022 - Arduino: lick: 7
# 00:11:27.039 - Arduino: 0
# 00:11:27.059 - Arduino: bar: 7
# 00:11:27.080 - Arduino: lick: 7
# 00:11:27.092 - Arduino: 0
# 00:11:27.112 - Arduino: bar: 6
# 00:11:27.133 - Arduino: lick: 8
# 00:11:27.149 - Arduino: 0
# 00:11:27.166 - Arduino: bar: 7
# 00:11:27.186 - Arduino: lick: 7
# 00:11:27.202 - Arduino: 0
# 00:11:27.223 - Arduino: bar: 6
# 00:11:27.239 - Arduino: lick: 8
# 00:11:27.256 - Arduino: 0
# 00:11:27.276 - Arduino: bar: 6
# 00:11:27.293 - Arduino: lick: 8
# 00:11:27.309 - Arduino: 0
# 00:11:27.329 - Arduino: bar: 5
# 00:11:27.346 - Arduino: lick: 7
# 00:11:27.362 - Arduino: 0
# 00:11:27.383 - Arduino: bar: 6
# 00:11:27.399 - Arduino: lick: 7
# 00:11:27.416 - Arduino: 0
# 00:11:27.436 - Arduino: bar: 7
# 00:11:27.452 - Arduino: lick: 7
# 00:11:27.469 - Arduino: 0
# 00:11:27.489 - Arduino: bar: 6
# 00:11:27.506 - Arduino: lick: 7
# 00:11:27.522 - Arduino: 0
# 00:11:27.543 - Arduino: bar: 6
# 00:11:27.559 - Arduino: lick: 8
# 00:11:27.575 - Arduino: 0
# 00:11:27.596 - Arduino: bar: 6
# 00:11:27.612 - Arduino: lick: 7
# 00:11:27.629 - Arduino: 0
# 00:11:27.649 - Arduino: bar: 6
# 00:11:27.666 - Arduino: lick: 8
# 00:11:27.682 - Arduino: 0
# 00:11:27.702 - Arduino: bar: 7
# 00:11:27.719 - Arduino: lick: 7
# 00:11:27.735 - Arduino: 0
# 00:11:27.756 - Arduino: bar: 7
# 00:11:27.772 - Arduino: lick: 7
# 00:11:27.788 - Arduino: 0
# 00:11:27.809 - Arduino: bar: 6
# 00:11:27.825 - Arduino: lick: 8
# 00:11:27.842 - Arduino: 0
# 00:11:27.862 - Arduino: bar: 6
# 00:11:27.878 - Arduino: lick: 8
# 00:11:27.895 - Arduino: 0
# 00:11:27.915 - Arduino: bar: 6
# 00:11:27.932 - Arduino: lick: 7
# 00:11:27.948 - Arduino: 0
# 00:11:27.969 - Arduino: bar: 7
# 00:11:27.985 - Arduino: lick: 7
# 00:11:28.001 - Arduino: 0
# 00:11:28.022 - Arduino: bar: 7
# 00:11:28.038 - Arduino: lick: 7
# 00:11:28.055 - Arduino: 0
# 00:11:28.075 - Arduino: bar: 7
# 00:11:28.091 - Arduino: lick: 7
# 00:11:28.108 - Arduino: 0
# 00:11:28.128 - Arduino: bar: 7
# 00:11:28.145 - Arduino: lick: 7
# 00:11:28.161 - Arduino: 0
# 00:11:28.182 - Arduino: bar: 6
# 00:11:28.198 - Arduino: lick: 8
# 00:11:28.214 - Arduino: 0
# 00:11:28.235 - Arduino: bar: 6
# 00:11:28.251 - Arduino: lick: 7
# 00:11:28.268 - Arduino: 0
# 00:11:28.288 - Arduino: bar: 7
# 00:11:28.304 - Arduino: lick: 7
# 00:11:28.321 - Arduino: 0
# 00:11:28.341 - Arduino: bar: 7
# 00:11:28.358 - Arduino: lick: 7
# 00:11:28.374 - Arduino: 0
# 00:11:28.394 - Arduino: bar: 6
# 00:11:28.411 - Arduino: lick: 7
# 00:11:28.427 - Arduino: 0
# 00:11:28.448 - Arduino: bar: 7
# 00:11:28.468 - Arduino: lick: 8
# 00:11:28.481 - Arduino: 0
# 00:11:28.501 - Arduino: bar: 7
# 00:11:28.521 - Arduino: lick: 8
# 00:11:28.538 - Arduino: 0
# 00:11:28.554 - Arduino: bar: 7
# 00:11:28.575 - Arduino: lick: 7
# 00:11:28.591 - Arduino: 0
# 00:11:28.611 - Arduino: bar: 7
# 00:11:28.628 - Arduino: lick: 7
# 00:11:28.644 - Arduino: 0
# 00:11:28.665 - Arduino: bar: 7
# 00:11:28.681 - Arduino: lick: 7
# 00:11:28.698 - Arduino: 0
# 00:11:28.718 - Arduino: bar: 9
# 00:11:28.734 - Arduino: lick: 8
# 00:11:28.751 - Arduino: 0
# 00:11:28.771 - Arduino: bar: 8
# 00:11:28.788 - Arduino: lick: 8
# 00:11:28.804 - Arduino: 0
# 00:11:28.825 - Arduino: bar: 9
# 00:11:28.841 - Arduino: lick: 8
# 00:11:28.857 - Arduino: 0
# 00:11:28.878 - Arduino: bar: 13
# 00:11:28.898 - Arduino: lick: 7
# 00:11:28.915 - Arduino: 0
# 00:11:28.935 - Arduino: bar: 14
# 00:11:28.952 - Arduino: lick: 7
# 00:11:28.968 - Arduino: 0
# 00:11:28.988 - Arduino: bar: 15
# 00:11:29.009 - Arduino: lick: 7
# 00:11:29.025 - Arduino: 0
# 00:11:29.046 - Arduino: bar: 13
# 00:11:29.062 - Arduino: lick: 8
# 00:11:29.079 - Arduino: 0
# 00:11:29.099 - Arduino: bar: 14
# 00:11:29.119 - Arduino: lick: 7
# 00:11:29.136 - Arduino: 0
# 00:11:29.156 - Arduino: bar: 14
# 00:11:29.173 - Arduino: lick: 7
# 00:11:29.189 - Arduino: 0
# 00:11:29.209 - Arduino: bar: 6
# 00:11:29.226 - Arduino: lick: 7
# 00:11:29.242 - Arduino: 0
# 00:11:29.263 - Arduino: bar: 8
# 00:11:29.279 - Arduino: lick: 7
# 00:11:29.296 - Arduino: 0
# 00:11:29.316 - Arduino: bar: 8
# 00:11:29.336 - Arduino: lick: 7
# 00:11:29.353 - Arduino: 0
# 00:11:29.373 - Arduino: bar: 9
# 00:11:29.390 - Arduino: lick: 7
# 00:11:29.406 - Arduino: 0
# 00:11:29.427 - Arduino: bar: 9
# 00:11:29.443 - Arduino: lick: 8
# 00:11:29.460 - Arduino: 0
# 00:11:29.480 - Arduino: bar: 9
# 00:11:29.496 - Arduino: lick: 8
# 00:11:29.513 - Arduino: 0
# 00:11:29.533 - Arduino: bar: 11
# 00:11:29.550 - Arduino: lick: 7
# 00:11:29.566 - Arduino: 0
# 00:11:29.590 - Arduino: bar: 10
# 00:11:29.607 - Arduino: lick: 7
# 00:11:29.623 - Arduino: 0
# 00:11:29.644 - Arduino: bar: 9
# 00:11:29.660 - Arduino: lick: 7
# 00:11:29.677 - Arduino: 0
# 00:11:29.697 - Arduino: bar: 9
# 00:11:29.713 - Arduino: lick: 7
# 00:11:29.730 - Arduino: 0
# 00:11:29.750 - Arduino: bar: 10
# 00:11:29.767 - Arduino: lick: 7
# 00:11:29.783 - Arduino: 0
# 00:11:29.807 - Arduino: bar: 10
# 00:11:29.824 - Arduino: lick: 7
# 00:11:29.840 - Arduino: 0
# 00:11:29.861 - Arduino: bar: 10
# 00:11:29.877 - Arduino: lick: 7
# 00:11:29.894 - Arduino: 0
# 00:11:29.914 - Arduino: bar: 9
# 00:11:29.930 - Arduino: lick: 8
# 00:11:29.947 - Arduino: 0
# 00:11:29.967 - Arduino: bar: 10
# 00:11:29.988 - Arduino: lick: 7
# 00:11:30.004 - Arduino: 0
# 00:11:30.025 - Arduino: bar: 9
# 00:11:30.042 - Arduino: lick: 7
# 00:11:30.058 - Arduino: 0
# 00:11:30.078 - Arduino: bar: 11
# 00:11:30.094 - Arduino: lick: 7
# 00:11:30.111 - Arduino: 0
# 00:11:30.131 - Arduino: bar: 12
# 00:11:30.151 - Arduino: lick: 7
# 00:11:30.168 - Arduino: 0
# 00:11:30.188 - Arduino: bar: 11
# 00:11:30.205 - Arduino: lick: 8
# 00:11:30.221 - Arduino: 0
# 00:11:30.242 - Arduino: bar: 10
# 00:11:30.258 - Arduino: lick: 7
# 00:11:30.275 - Arduino: 0
# 00:11:30.295 - Arduino: bar: 11
# 00:11:30.315 - Arduino: lick: 7
# 00:11:30.332 - Arduino: 0
# 00:11:30.352 - Arduino: bar: 11
# 00:11:30.369 - Arduino: lick: 7
# 00:11:30.385 - Arduino: 0
# 00:11:30.405 - Arduino: bar: 11
# 00:11:30.422 - Arduino: lick: 7
# 00:11:30.438 - Arduino: 0
# 00:11:30.463 - Arduino: bar: 11
# 00:11:30.479 - Arduino: lick: 8
# 00:11:30.496 - Arduino: 0
# 00:11:30.516 - Arduino: bar: 13
# 00:11:30.533 - Arduino: lick: 7
# 00:11:30.549 - Arduino: 0
# 00:11:30.569 - Arduino: bar: 11
# 00:11:30.590 - Arduino: lick: 7
# 00:11:30.606 - Arduino: 0
# 00:11:30.627 - Arduino: bar: 12
# 00:11:30.643 - Arduino: lick: 8
# 00:11:30.660 - Arduino: 0
# 00:11:30.680 - Arduino: bar: 11
# 00:11:30.696 - Arduino: lick: 7
# 00:11:30.713 - Arduino: 0
# 00:11:30.733 - Arduino: bar: 11
# 00:11:30.754 - Arduino: lick: 7
# 00:11:30.770 - Arduino: 0
# 00:11:30.790 - Arduino: bar: 11
# 00:11:30.807 - Arduino: lick: 8
# 00:11:30.824 - Arduino: 0
# 00:11:30.844 - Arduino: bar: 11
# 00:11:30.860 - Arduino: lick: 7
# 00:11:30.877 - Arduino: 0
# 00:11:30.901 - Arduino: bar: 14
# 00:11:30.918 - Arduino: lick: 7
# 00:11:30.934 - Arduino: 0
# 00:11:30.954 - Arduino: bar: 13
# 00:11:30.971 - Arduino: lick: 7
# 00:11:30.987 - Arduino: 0
# 00:11:31.012 - Arduino: bar: 11
# 00:11:31.028 - Arduino: lick: 7
# 00:11:31.045 - Arduino: 0
# 00:11:31.065 - Arduino: bar: 12
# 00:11:31.081 - Arduino: lick: 7
# 00:11:31.098 - Arduino: 0
# 00:11:31.118 - Arduino: bar: 11
# 00:11:31.135 - Arduino: lick: 8
# 00:11:31.155 - Arduino: 0
# 00:11:31.175 - Arduino: bar: 11
# 00:11:31.192 - Arduino: lick: 8
# 00:11:31.208 - Arduino: 0
# 00:11:31.229 - Arduino: bar: 10
# 00:11:31.245 - Arduino: lick: 7
# 00:11:31.262 - Arduino: 0
# 00:11:31.282 - Arduino: bar: 11
# 00:11:31.302 - Arduino: lick: 7
# 00:11:31.319 - Arduino: 0
# 00:11:31.339 - Arduino: bar: 11
# 00:11:31.356 - Arduino: lick: 7
# 00:11:31.372 - Arduino: 0
# 00:11:31.393 - Arduino: bar: 10
# 00:11:31.409 - Arduino: lick: 8
# 00:11:31.426 - Arduino: 0
# 00:11:31.446 - Arduino: bar: 10
# 00:11:31.466 - Arduino: lick: 8
# 00:11:31.483 - Arduino: 0
# 00:11:31.503 - Arduino: bar: 11
# 00:11:31.520 - Arduino: lick: 7
# 00:11:31.536 - Arduino: 0
# 00:11:31.556 - Arduino: bar: 12
# 00:11:31.573 - Arduino: lick: 8
# 00:11:31.593 - Arduino: 0
# 00:11:31.614 - Arduino: bar: 11
# 00:11:31.630 - Arduino: lick: 8
# 00:11:31.647 - Arduino: 0
# 00:11:31.667 - Arduino: bar: 23
# 00:11:31.687 - Arduino: lick: 7
# 00:11:31.704 - Arduino: 0
# 00:11:31.724 - Arduino: bar: 12
# 00:11:31.741 - Arduino: lick: 8
# 00:11:31.757 - Arduino: 0
# 00:11:31.778 - Arduino: bar: 13
# 00:11:31.798 - Arduino: lick: 8
# 00:11:31.815 - Arduino: 0
# 00:11:31.835 - Arduino: bar: 11
# 00:11:31.855 - Arduino: lick: 7
# 00:11:31.872 - Arduino: 0
# 00:11:31.892 - Arduino: bar: 12
# 00:11:31.909 - Arduino: lick: 8
# 00:11:31.925 - Arduino: 0
# 00:11:31.946 - Arduino: bar: 13
# 00:11:31.962 - Arduino: lick: 7
# 00:11:31.978 - Arduino: 0
# 00:11:32.032 - Arduino: bar: 16
# 00:11:32.048 - Arduino: lick: 7
# 00:11:32.068 - Arduino: 0
# 00:11:32.089 - Arduino: bar: 15
# 00:11:32.105 - Arduino: lick: 7
# 00:11:32.122 - Arduino: 0
# 00:11:32.187 - Arduino: bar: 15
# 00:11:32.207 - Arduino: lick: 7
# 00:11:32.224 - Arduino: 0
# 00:11:32.245 - Arduino: bar: 13
# 00:11:32.261 - Arduino: lick: 7
# 00:11:32.277 - Arduino: 0
# 00:11:32.298 - Arduino: bar: 16
# 00:11:32.318 - Arduino: lick: 7
# 00:11:32.335 - Arduino: 0
# 00:11:32.355 - Arduino: bar: 15
# 00:11:32.372 - Arduino: lick: 7
# 00:11:32.388 - Arduino: 0
# 00:11:32.408 - Arduino: bar: 13
# 00:11:32.429 - Arduino: lick: 7
# 00:11:32.445 - Arduino: 0
# 00:11:32.466 - Arduino: bar: 17
# 00:11:32.482 - Arduino: lick: 7
# 00:11:32.499 - Arduino: 0
# 00:11:32.523 - Arduino: bar: 15
# 00:11:32.539 - Arduino: lick: 7
# 00:11:32.556 - Arduino: 0
# 00:11:32.576 - Arduino: bar: 14
# 00:11:32.593 - Arduino: lick: 7
# 00:11:32.613 - Arduino: 0
# 00:11:32.634 - Arduino: bar: 16
# 00:11:32.650 - Arduino: lick: 7
# 00:11:32.667 - Arduino: 0
# 00:11:32.687 - Arduino: bar: 15
# 00:11:32.707 - Arduino: lick: 7
# 00:11:32.724 - Arduino: 0
# 00:11:32.744 - Arduino: bar: 14
# 00:11:32.761 - Arduino: lick: 7
# 00:11:32.777 - Arduino: 0
# 00:11:32.797 - Arduino: bar: 21
# 00:11:32.818 - Arduino: lick: 7
# 00:11:32.834 - Arduino: 0
# 00:11:32.855 - Arduino: bar: 15
# 00:11:32.871 - Arduino: lick: 7
# 00:11:32.892 - Arduino: 0
# 00:11:32.912 - Arduino: bar: 14
# 00:11:32.929 - Arduino: lick: 7
# 00:11:32.945 - Arduino: 0
# 00:11:32.965 - Arduino: bar: 21
# 00:11:32.986 - Arduino: lick: 7
# 00:11:33.002 - Arduino: 0
# 00:11:33.023 - Arduino: bar: 15
# 00:11:33.039 - Arduino: lick: 8
# 00:11:33.059 - Arduino: 0
# 00:11:33.080 - Arduino: bar: 13
# 00:11:33.097 - Arduino: lick: 8
# 00:11:33.113 - Arduino: 0
# 00:11:33.133 - Arduino: bar: 14
# 00:11:33.150 - Arduino: lick: 8
# 00:11:33.170 - Arduino: 0
# 00:11:33.191 - Arduino: bar: 14
# 00:11:33.207 - Arduino: lick: 7
# 00:11:33.224 - Arduino: 0
# 00:11:33.244 - Arduino: bar: 13
# 00:11:33.260 - Arduino: lick: 8
# 00:11:33.281 - Arduino: 0
# 00:11:33.301 - Arduino: bar: 14
# 00:11:33.318 - Arduino: lick: 7
# 00:11:33.334 - Arduino: 0
# 00:11:33.354 - Arduino: bar: 14
# 00:11:33.375 - Arduino: lick: 7
# 00:11:33.391 - Arduino: 0
# 00:11:33.412 - Arduino: bar: 13
# 00:11:33.428 - Arduino: lick: 7
# 00:11:33.445 - Arduino: 0
# 00:11:33.465 - Arduino: bar: 15
# 00:11:33.485 - Arduino: lick: 7
# 00:11:33.502 - Arduino: 0
# 00:11:33.522 - Arduino: bar: 15
# 00:11:33.539 - Arduino: lick: 7
# 00:11:33.555 - Arduino: 0
# 00:11:33.576 - Arduino: bar: 14
# 00:11:33.596 - Arduino: lick: 7
# 00:11:33.612 - Arduino: 0
# 00:11:33.633 - Arduino: bar: 15
# 00:11:33.649 - Arduino: lick: 7
# 00:11:33.666 - Arduino: 0
# 00:11:33.686 - Arduino: bar: 14
# 00:11:33.707 - Arduino: lick: 8
# 00:11:33.723 - Arduino: 0
# 00:11:33.744 - Arduino: bar: 13
# 00:11:33.760 - Arduino: lick: 8
# 00:11:33.777 - Arduino: 0
# 00:11:33.797 - Arduino: bar: 16
# 00:11:33.817 - Arduino: lick: 7
# 00:11:33.834 - Arduino: 0
# 00:11:33.854 - Arduino: bar: 15
# 00:11:33.871 - Arduino: lick: 8
# 00:11:33.891 - Arduino: 0
# 00:11:33.911 - Arduino: bar: 14
# 00:11:33.928 - Arduino: lick: 8
# 00:11:33.944 - Arduino: 0
# 00:11:33.969 - Arduino: bar: 25
# 00:11:33.985 - Arduino: lick: 7
# 00:11:34.002 - Arduino: 0
# 00:11:34.022 - Arduino: bar: 15
# 00:11:34.042 - Arduino: lick: 7
# 00:11:34.059 - Arduino: 0
# 00:11:34.079 - Arduino: bar: 13
# 00:11:34.096 - Arduino: lick: 7
# 00:11:34.112 - Arduino: 0
# 00:11:34.137 - Arduino: bar: 15
# 00:11:34.153 - Arduino: lick: 7
# 00:11:34.170 - Arduino: 0
# 00:11:34.190 - Arduino: bar: 14
# 00:11:34.206 - Arduino: lick: 7
# 00:11:34.223 - Arduino: 0
# 00:11:34.247 - Arduino: bar: 14
# 00:11:34.264 - Arduino: lick: 7
# 00:11:34.280 - Arduino: 0
# 00:11:34.301 - Arduino: bar: 13
# 00:11:34.317 - Arduino: lick: 8
# 00:11:34.334 - Arduino: 0
# 00:11:34.358 - Arduino: bar: 14
# 00:11:34.374 - Arduino: lick: 7
# 00:11:34.391 - Arduino: 0
# 00:11:34.411 - Arduino: bar: 13
# 00:11:34.428 - Arduino: lick: 8
# 00:11:34.444 - Arduino: 0
# 00:11:34.468 - Arduino: bar: 14
# 00:11:34.485 - Arduino: lick: 7
# 00:11:34.501 - Arduino: 0
# 00:11:34.522 - Arduino: bar: 15
# 00:11:34.538 - Arduino: lick: 7
# 00:11:34.555 - Arduino: 0
# 00:11:34.579 - Arduino: bar: 14
# 00:11:34.596 - Arduino: lick: 8
# 00:11:34.612 - Arduino: 0
# 00:11:34.632 - Arduino: bar: 14
# 00:11:34.649 - Arduino: lick: 7
# 00:11:34.665 - Arduino: 0
# 00:11:34.690 - Arduino: bar: 15
# 00:11:34.706 - Arduino: lick: 7
# 00:11:34.723 - Arduino: 0
# 00:11:34.743 - Arduino: bar: 14
# 00:11:34.759 - Arduino: lick: 7
# 00:11:34.780 - Arduino: 0
# 00:11:34.800 - Arduino: bar: 15
# 00:11:34.817 - Arduino: lick: 7
# 00:11:34.833 - Arduino: 0
# 00:11:34.854 - Arduino: bar: 15
# 00:11:34.874 - Arduino: lick: 8
# 00:11:34.890 - Arduino: 0
# 00:11:34.911 - Arduino: bar: 28
# 00:11:34.927 - Arduino: lick: 7
# 00:11:34.944 - Arduino: 0
# 00:11:35.079 - Arduino: bar: 2156
# 00:11:35.226 - Arduino: lick: 8
# 00:11:35.362 - Arduino: 0
# 00:11:35.529 - Arduino: bar: 1896
# 00:11:35.652 - Arduino: lick: 7
# 00:11:35.771 - Arduino: 0
# 00:11:35.927 - Arduino: bar: 1496
# 00:11:36.046 - Arduino: lick: 7
# 00:11:36.070 - Arduino: 0
# 00:11:36.094 - Arduino: bar: 14
# 00:11:36.111 - Arduino: lick: 8
# 00:11:36.127 - Arduino: 0
# 00:11:36.148 - Arduino: bar: 16
# 00:11:36.164 - Arduino: lick: 7
# 00:11:36.181 - Arduino: 0
# 00:11:36.205 - Arduino: bar: 15
# 00:11:36.222 - Arduino: lick: 8
# 00:11:36.238 - Arduino: 0
# 00:11:36.258 - Arduino: bar: 14
# 00:11:36.275 - Arduino: lick: 8
# 00:11:36.295 - Arduino: 0
# 00:11:36.316 - Arduino: bar: 16
# 00:11:36.332 - Arduino: lick: 7
# 00:11:36.349 - Arduino: 0
# 00:11:36.369 - Arduino: bar: 15
# 00:11:36.389 - Arduino: lick: 8
# 00:11:36.406 - Arduino: 0
# 00:11:36.426 - Arduino: bar: 13
# 00:11:36.443 - Arduino: lick: 7
# 00:11:36.459 - Arduino: 0
# 00:11:36.479 - Arduino: bar: 16
# 00:11:36.500 - Arduino: lick: 7
# 00:11:36.516 - Arduino: 0
# 00:11:36.537 - Arduino: bar: 14
# 00:11:36.553 - Arduino: lick: 7
# 00:11:36.570 - Arduino: 0
# 00:11:36.590 - Arduino: bar: 14
# 00:11:36.611 - Arduino: lick: 8
# 00:11:36.627 - Arduino: 0
# 00:11:36.647 - Arduino: bar: 16
# 00:11:36.664 - Arduino: lick: 7
# 00:11:36.680 - Arduino: 0
# 00:11:36.705 - Arduino: bar: 15
# 00:11:36.721 - Arduino: lick: 7
# 00:11:36.738 - Arduino: 0
# 00:11:36.758 - Arduino: bar: 13
# 00:11:36.774 - Arduino: lick: 7
# 00:11:36.791 - Arduino: 0
# 00:11:36.815 - Arduino: bar: 17
# 00:11:36.832 - Arduino: lick: 7
# 00:11:36.848 - Arduino: 0
# 00:11:36.869 - Arduino: bar: 14
# 00:11:36.885 - Arduino: lick: 7
# 00:11:36.905 - Arduino: 0
# 00:11:36.926 - Arduino: bar: 13
# 00:11:36.942 - Arduino: lick: 7
# 00:11:36.959 - Arduino: 0
# 00:11:36.979 - Arduino: bar: 16
# 00:11:36.996 - Arduino: lick: 7
# 00:11:37.016 - Arduino: 0
# 00:11:37.037 - Arduino: bar: 14
# 00:11:37.053 - Arduino: lick: 6
# 00:11:37.070 - Arduino: 0
# 00:11:37.090 - Arduino: bar: 13
# 00:11:37.110 - Arduino: lick: 7
# 00:11:37.127 - Arduino: 0
# 00:11:37.147 - Arduino: bar: 15
# 00:11:37.164 - Arduino: lick: 7
# 00:11:37.180 - Arduino: 0
# 00:11:37.200 - Arduino: bar: 14
# 00:11:37.221 - Arduino: lick: 7
# 00:11:37.237 - Arduino: 0
# 00:11:37.258 - Arduino: bar: 13
# 00:11:37.274 - Arduino: lick: 7
# 00:11:37.291 - Arduino: 0
# 00:11:37.311 - Arduino: bar: 15
# 00:11:37.331 - Arduino: lick: 7
# 00:11:37.348 - Arduino: 0
# 00:11:37.368 - Arduino: bar: 14
# 00:11:37.385 - Arduino: lick: 7
# 00:11:37.401 - Arduino: 0
# 00:11:37.421 - Arduino: bar: 12
# 00:11:37.442 - Arduino: lick: 8
# 00:11:37.458 - Arduino: 0
# 00:11:37.479 - Arduino: bar: 15
# 00:11:37.495 - Arduino: lick: 7
# 00:11:37.512 - Arduino: 0
# 00:11:37.532 - Arduino: bar: 13
# 00:11:37.553 - Arduino: lick: 7
# 00:11:37.569 - Arduino: 0
# 00:11:37.589 - Arduino: bar: 12
# 00:11:37.606 - Arduino: lick: 7
# 00:11:37.622 - Arduino: 0
# 00:11:37.643 - Arduino: bar: 13
# 00:11:37.663 - Arduino: lick: 7
# 00:11:37.680 - Arduino: 0
# 00:11:37.700 - Arduino: bar: 13
# 00:11:37.717 - Arduino: lick: 7
# 00:11:37.733 - Arduino: 0
# 00:11:37.753 - Arduino: bar: 13
# 00:11:37.770 - Arduino: lick: 7
# 00:11:37.790 - Arduino: 0
# 00:11:37.811 - Arduino: bar: 13
# 00:11:37.827 - Arduino: lick: 8
# 00:11:37.844 - Arduino: 0
# 00:11:37.864 - Arduino: bar: 14
# 00:11:37.880 - Arduino: lick: 7
# 00:11:37.901 - Arduino: 0
# 00:11:37.921 - Arduino: bar: 14
# 00:11:37.938 - Arduino: lick: 8
# 00:11:37.954 - Arduino: 0
# 00:11:37.974 - Arduino: bar: 13
# 00:11:37.991 - Arduino: lick: 7
# 00:11:38.011 - Arduino: 0
# 00:11:38.032 - Arduino: bar: 14
# 00:11:38.048 - Arduino: lick: 7
# 00:11:38.065 - Arduino: 0
# 00:11:38.085 - Arduino: bar: 14
# 00:11:38.102 - Arduino: lick: 7
# 00:11:38.122 - Arduino: 0
# 00:11:38.142 - Arduino: bar: 13
# 00:11:38.159 - Arduino: lick: 7
# 00:11:38.175 - Arduino: 0
# 00:11:38.196 - Arduino: bar: 16
# 00:11:38.212 - Arduino: lick: 7
# 00:11:38.232 - Arduino: 0
# 00:11:38.253 - Arduino: bar: 13
# 00:11:38.269 - Arduino: lick: 7
# 00:11:38.286 - Arduino: 0
# 00:11:38.306 - Arduino: bar: 13
# 00:11:38.323 - Arduino: lick: 8
# 00:11:38.343 - Arduino: 0
# 00:11:38.364 - Arduino: bar: 15
# 00:11:38.380 - Arduino: lick: 7
# 00:11:38.397 - Arduino: 0
# 00:11:38.458 - Arduino: bar: 14
# 00:11:38.474 - Arduino: lick: 7
# 00:11:38.491 - Arduino: 0
# 00:11:38.515 - Arduino: bar: 15
# 00:11:38.532 - Arduino: lick: 8
# 00:11:38.577 - Arduino: 0
# 00:11:38.618 - Arduino: bar: 14
# 00:11:38.638 - Arduino: lick: 7
# 00:11:38.654 - Arduino: 0
# 00:11:38.675 - Arduino: bar: 13
# 00:11:38.691 - Arduino: lick: 7
# 00:11:38.708 - Arduino: 0
# 00:11:38.728 - Arduino: bar: 16
# 00:11:38.748 - Arduino: lick: 7
# 00:11:38.765 - Arduino: 0
# 00:11:38.785 - Arduino: bar: 14
# 00:11:38.802 - Arduino: lick: 7
# 00:11:38.818 - Arduino: 0
# 00:11:38.839 - Arduino: bar: 12
# 00:11:38.859 - Arduino: lick: 7
# 00:11:38.876 - Arduino: 0
# 00:11:38.896 - Arduino: bar: 14
# 00:11:38.913 - Arduino: lick: 7
# 00:11:38.929 - Arduino: 0
# 00:11:38.949 - Arduino: bar: 14
# 00:11:38.970 - Arduino: lick: 7
# 00:11:38.986 - Arduino: 0
# 00:11:39.007 - Arduino: bar: 14
# 00:11:39.023 - Arduino: lick: 7
# 00:11:39.040 - Arduino: 0
# 00:11:39.060 - Arduino: bar: 13
# 00:11:39.080 - Arduino: lick: 8
# 00:11:39.097 - Arduino: 0
# 00:11:39.117 - Arduino: bar: 19
# 00:11:39.134 - Arduino: lick: 7
# 00:11:39.150 - Arduino: 0
# 00:11:39.175 - Arduino: bar: 17
# 00:11:39.191 - Arduino: lick: 8
# 00:11:39.208 - Arduino: 0
# 00:11:39.228 - Arduino: bar: 19
# 00:11:39.248 - Arduino: lick: 7
# 00:11:39.265 - Arduino: 0
# 00:11:39.285 - Arduino: bar: 14
# 00:11:39.302 - Arduino: lick: 7
# 00:11:39.318 - Arduino: 0
# 00:11:39.342 - Arduino: bar: 14
# 00:11:39.359 - Arduino: lick: 7
# 00:11:39.375 - Arduino: 0
# 00:11:39.396 - Arduino: bar: 16
# 00:11:39.412 - Arduino: lick: 7
# 00:11:39.429 - Arduino: 0
# 00:11:39.453 - Arduino: bar: 14
# 00:11:39.470 - Arduino: lick: 7
# 00:11:39.486 - Arduino: 0
# 00:11:39.506 - Arduino: bar: 13
# 00:11:39.523 - Arduino: lick: 7
# 00:11:39.539 - Arduino: 0
# 00:11:39.564 - Arduino: bar: 17
# 00:11:39.580 - Arduino: lick: 7
# 00:11:39.597 - Arduino: 0
# 00:11:39.617 - Arduino: bar: 15
# 00:11:39.633 - Arduino: lick: 7
# 00:11:39.654 - Arduino: 0
# 00:11:39.674 - Arduino: bar: 13
# 00:11:39.691 - Arduino: lick: 8
# 00:11:39.707 - Arduino: 0
# 00:11:39.727 - Arduino: bar: 16
# 00:11:39.748 - Arduino: lick: 7
# 00:11:39.764 - Arduino: 0
# 00:11:39.785 - Arduino: bar: 14
# 00:11:39.801 - Arduino: lick: 7
# 00:11:39.818 - Arduino: 0
# 00:11:39.838 - Arduino: bar: 14
# 00:11:39.858 - Arduino: lick: 7
# 00:11:39.875 - Arduino: 0
# 00:11:39.895 - Arduino: bar: 16
# 00:11:39.912 - Arduino: lick: 7
# 00:11:39.928 - Arduino: 0
# 00:11:39.949 - Arduino: bar: 15
# 00:11:39.969 - Arduino: lick: 7
# 00:11:39.986 - Arduino: 0
# 00:11:40.006 - Arduino: bar: 14
# 00:11:40.022 - Arduino: lick: 7
# 00:11:40.039 - Arduino: 0
# 00:11:40.059 - Arduino: bar: 15
# 00:11:40.080 - Arduino: lick: 7
# 00:11:40.096 - Arduino: 0
# 00:11:40.117 - Arduino: bar: 15
# 00:11:40.133 - Arduino: lick: 7
# 00:11:40.150 - Arduino: 0
# 00:11:40.174 - Arduino: bar: 13
# 00:11:40.190 - Arduino: lick: 8
# 00:11:40.207 - Arduino: 0
# 00:11:40.227 - Arduino: bar: 15
# 00:11:40.244 - Arduino: lick: 8
# 00:11:40.260 - Arduino: 0
# 00:11:40.284 - Arduino: bar: 14
# 00:11:40.301 - Arduino: lick: 8
# 00:11:40.318 - Arduino: 0
# 00:11:40.338 - Arduino: bar: 13
# 00:11:40.354 - Arduino: lick: 8
# 00:11:40.371 - Arduino: 0
# 00:11:40.395 - Arduino: bar: 14
# 00:11:40.412 - Arduino: lick: 8
# 00:11:40.428 - Arduino: 0
# 00:11:40.448 - Arduino: bar: 14
# 00:11:40.465 - Arduino: lick: 7
# 00:11:40.481 - Arduino: 0
# 00:11:40.506 - Arduino: bar: 14
# 00:11:40.522 - Arduino: lick: 8
# 00:11:40.539 - Arduino: 0
# 00:11:40.559 - Arduino: bar: 14
# 00:11:40.575 - Arduino: lick: 7
# 00:11:40.592 - Arduino: 0
# 00:11:40.616 - Arduino: bar: 14
# 00:11:40.633 - Arduino: lick: 7
# 00:11:40.649 - Arduino: 0
# 00:11:40.669 - Arduino: bar: 14
# 00:11:40.686 - Arduino: lick: 7
# 00:11:40.703 - Arduino: 0
# 00:11:40.727 - Arduino: bar: 13
# 00:11:40.743 - Arduino: lick: 7
# 00:11:40.760 - Arduino: 0
# 00:11:40.780 - Arduino: bar: 15
# 00:11:40.797 - Arduino: lick: 8
# 00:11:40.813 - Arduino: 0
# 00:11:40.837 - Arduino: bar: 15
# 00:11:40.854 - Arduino: lick: 8
# 00:11:40.871 - Arduino: 0
# 00:11:40.891 - Arduino: bar: 14
# 00:11:40.907 - Arduino: lick: 8
# 00:11:40.927 - Arduino: 0
# 00:11:40.948 - Arduino: bar: 15
# 00:11:40.965 - Arduino: lick: 7
# 00:11:40.981 - Arduino: 0
# 00:11:41.001 - Arduino: bar: 15
# 00:11:41.022 - Arduino: lick: 8
# 00:11:41.038 - Arduino: 0
# 00:11:41.059 - Arduino: bar: 14
# 00:11:41.075 - Arduino: lick: 7
# 00:11:41.092 - Arduino: 0
# 00:11:41.112 - Arduino: bar: 15
# 00:11:41.132 - Arduino: lick: 7
# 00:11:41.149 - Arduino: 0
# 00:11:41.169 - Arduino: bar: 14
# 00:11:41.186 - Arduino: lick: 8
# 00:11:41.202 - Arduino: 0
# 00:11:41.222 - Arduino: bar: 14
# 00:11:41.243 - Arduino: lick: 8
# 00:11:41.260 - Arduino: 0
# 00:11:41.280 - Arduino: bar: 16
# 00:11:41.296 - Arduino: lick: 7
# 00:11:41.313 - Arduino: 0
# 00:11:41.341 - Arduino: bar: 215
# 00:11:41.395 - Arduino: lick: 8
# 00:11:41.493 - Arduino: 0
# 00:11:41.624 - Arduino: bar: 1326
# 00:11:41.714 - Arduino: lick: 7
# 00:11:41.776 - Arduino: 0
# 00:11:41.796 - Arduino: bar: 17
# 00:11:41.812 - Arduino: lick: 7
# 00:11:41.833 - Arduino: 0
# 00:11:41.890 - Arduino: bar: 699
# 00:11:41.915 - Arduino: lick: 7
# 00:11:41.931 - Arduino: 0
# 00:11:41.952 - Arduino: bar: 13
# 00:11:41.968 - Arduino: lick: 8
# 00:11:41.985 - Arduino: 0
# 00:11:42.005 - Arduino: bar: 13
# 00:11:42.025 - Arduino: lick: 7
# 00:11:42.042 - Arduino: 0
# 00:11:42.062 - Arduino: bar: 15
# 00:11:42.079 - Arduino: lick: 7
# 00:11:42.095 - Arduino: 0
# 00:11:42.115 - Arduino: bar: 14
# 00:11:42.136 - Arduino: lick: 7
# 00:11:42.152 - Arduino: 0
# 00:11:42.173 - Arduino: bar: 12
# 00:11:42.189 - Arduino: lick: 8
# 00:11:42.206 - Arduino: 0
# 00:11:42.230 - Arduino: bar: 16
# 00:11:42.247 - Arduino: lick: 7
# 00:11:42.263 - Arduino: 0
# 00:11:42.283 - Arduino: bar: 14
# 00:11:42.300 - Arduino: lick: 7
# 00:11:42.316 - Arduino: 0
# 00:11:42.341 - Arduino: bar: 13
# 00:11:42.357 - Arduino: lick: 7
# 00:11:42.374 - Arduino: 0
# 00:11:42.398 - Arduino: bar: 254
# 00:11:42.443 - Arduino: lick: 8
# 00:11:42.492 - Arduino: 0
# 00:11:42.558 - Arduino: bar: 573
# 00:11:42.611 - Arduino: lick: 7
# 00:11:42.660 - Arduino: 0
# 00:11:42.726 - Arduino: bar: 573
# 00:11:42.775 - Arduino: lick: 8
# 00:11:42.828 - Arduino: 0
# 00:11:42.894 - Arduino: bar: 565
# 00:11:42.943 - Arduino: lick: 7
# 00:11:42.992 - Arduino: 0
# 00:11:43.057 - Arduino: bar: 573
# 00:11:43.111 - Arduino: lick: 8
# 00:11:43.160 - Arduino: 0
# 00:11:43.217 - Arduino: bar: 249
# 00:11:43.242 - Arduino: lick: 8
# 00:11:43.271 - Arduino: 0
# 00:11:43.307 - Arduino: bar: 149
# 00:11:43.340 - Arduino: lick: 8
# 00:11:43.373 - Arduino: 0
# 00:11:43.422 - Arduino: bar: 453
# 00:11:43.459 - Arduino: lick: 8
# 00:11:43.479 - Arduino: 0
# 00:11:43.500 - Arduino: bar: 12
# 00:11:43.516 - Arduino: lick: 7
# 00:11:43.533 - Arduino: 0
# 00:11:43.553 - Arduino: bar: 13
# 00:11:43.570 - Arduino: lick: 8
# 00:11:43.590 - Arduino: 0
# 00:11:43.610 - Arduino: bar: 13
# 00:11:43.627 - Arduino: lick: 8
# 00:11:43.643 - Arduino: 0
# 00:11:43.664 - Arduino: bar: 12
# 00:11:43.680 - Arduino: lick: 7
# 00:11:43.697 - Arduino: 0
# 00:11:43.721 - Arduino: bar: 12
# 00:11:43.737 - Arduino: lick: 7
# 00:11:43.754 - Arduino: 0
# 00:11:43.774 - Arduino: bar: 12
# 00:11:43.791 - Arduino: lick: 8
# 00:11:43.807 - Arduino: 0
# 00:11:43.827 - Arduino: bar: 13
# 00:11:43.848 - Arduino: lick: 7
# 00:11:43.864 - Arduino: 0
# 00:11:43.885 - Arduino: bar: 13
# 00:11:43.901 - Arduino: lick: 7
# 00:11:43.922 - Arduino: 0
# 00:11:43.975 - Arduino: bar: 581
# 00:11:44.024 - Arduino: lick: 7
# 00:11:44.077 - Arduino: 0
# 00:11:44.143 - Arduino: bar: 573
# 00:11:44.192 - Arduino: lick: 8
# 00:11:44.241 - Arduino: 0
# 00:11:44.307 - Arduino: bar: 566
# 00:11:44.356 - Arduino: lick: 7
# 00:11:44.372 - Arduino: 0
# 00:11:44.393 - Arduino: bar: 15
# 00:11:44.413 - Arduino: lick: 7
# 00:11:44.429 - Arduino: 0
# 00:11:44.450 - Arduino: bar: 14
# 00:11:44.466 - Arduino: lick: 7
# 00:11:44.483 - Arduino: 0
# 00:11:44.503 - Arduino: bar: 13
# 00:11:44.524 - Arduino: lick: 8
# 00:11:44.540 - Arduino: 0
# 00:11:44.560 - Arduino: bar: 16
# 00:11:44.577 - Arduino: lick: 7
# 00:11:44.593 - Arduino: 0
# 00:11:44.614 - Arduino: bar: 14
# 00:11:44.634 - Arduino: lick: 7
# 00:11:44.651 - Arduino: 0
# 00:11:44.671 - Arduino: bar: 13
# 00:11:44.688 - Arduino: lick: 7
# 00:11:44.704 - Arduino: 0
# 00:11:44.724 - Arduino: bar: 14
# 00:11:44.745 - Arduino: lick: 7
# 00:11:44.761 - Arduino: 0
# 00:11:44.790 - Arduino: bar: 251
# 00:11:44.843 - Arduino: lick: 8
# 00:11:44.893 - Arduino: 0
# 00:11:44.958 - Arduino: bar: 574
# 00:11:45.007 - Arduino: lick: 8
# 00:11:45.060 - Arduino: 0
# 00:11:45.126 - Arduino: bar: 574
# 00:11:45.175 - Arduino: lick: 8
# 00:11:45.224 - Arduino: 0
# 00:11:45.290 - Arduino: bar: 572
# 00:11:45.343 - Arduino: lick: 8
# 00:11:45.392 - Arduino: 0
# 00:11:45.453 - Arduino: bar: 517
# 00:11:45.482 - Arduino: lick: 7
# 00:11:45.499 - Arduino: 0
# 00:11:45.519 - Arduino: bar: 12
# 00:11:45.535 - Arduino: lick: 7
# 00:11:45.552 - Arduino: 0
# 00:11:45.572 - Arduino: bar: 13
# 00:11:45.593 - Arduino: lick: 8
# 00:11:45.609 - Arduino: 0
# 00:11:45.629 - Arduino: bar: 13
# 00:11:45.646 - Arduino: lick: 7
# 00:11:45.662 - Arduino: 0
# 00:11:45.683 - Arduino: bar: 13
# 00:11:45.703 - Arduino: lick: 8
# 00:11:45.720 - Arduino: 0
# 00:11:45.740 - Arduino: bar: 12
# 00:11:45.757 - Arduino: lick: 8
# 00:11:45.773 - Arduino: 0
# 00:11:45.793 - Arduino: bar: 13
# 00:11:45.814 - Arduino: lick: 7
# 00:11:45.830 - Arduino: 0
# 00:11:45.851 - Arduino: bar: 13
# 00:11:45.867 - Arduino: lick: 8
# 00:11:45.884 - Arduino: 0
# 00:11:45.904 - Arduino: bar: 12
# 00:11:45.920 - Arduino: lick: 7
# 00:11:45.941 - Arduino: 0
# 00:11:45.961 - Arduino: bar: 15
# 00:11:45.978 - Arduino: lick: 7
# 00:11:45.994 - Arduino: 0
# 00:11:46.014 - Arduino: bar: 14
# 00:11:46.031 - Arduino: lick: 7
# 00:11:46.051 - Arduino: 0
# 00:11:46.072 - Arduino: bar: 13
# 00:11:46.088 - Arduino: lick: 8
# 00:11:46.105 - Arduino: 0
# 00:11:46.125 - Arduino: bar: 14
# 00:11:46.142 - Arduino: lick: 7
# 00:11:46.162 - Arduino: 0
# 00:11:46.182 - Arduino: bar: 14
# 00:11:46.199 - Arduino: lick: 7
# 00:11:46.215 - Arduino: 0
# 00:11:46.236 - Arduino: bar: 13
# 00:11:46.252 - Arduino: lick: 7
# 00:11:46.272 - Arduino: 0
# 00:11:46.293 - Arduino: bar: 14
# 00:11:46.310 - Arduino: lick: 7
# 00:11:46.326 - Arduino: 0
# 00:11:46.346 - Arduino: bar: 13
# 00:11:46.363 - Arduino: lick: 7
# 00:11:46.379 - Arduino: 0
# 00:11:46.404 - Arduino: bar: 13
# 00:11:46.420 - Arduino: lick: 8
# 00:11:46.437 - Arduino: 0
# 00:11:46.457 - Arduino: bar: 12
# 00:11:46.473 - Arduino: lick: 7
# 00:11:46.490 - Arduino: 0
# 00:11:46.510 - Arduino: bar: 13
# 00:11:46.531 - Arduino: lick: 7
# 00:11:46.547 - Arduino: 0
# 00:11:46.567 - Arduino: bar: 13
# 00:11:46.584 - Arduino: lick: 7
# 00:11:46.600 - Arduino: 0
# 00:11:46.621 - Arduino: bar: 13
# 00:11:46.641 - Arduino: lick: 7
# 00:11:46.658 - Arduino: 0
# 00:11:46.678 - Arduino: bar: 13
# 00:11:46.695 - Arduino: lick: 8
# 00:11:46.711 - Arduino: 0
# 00:11:46.731 - Arduino: bar: 13
# 00:11:46.752 - Arduino: lick: 8
# 00:11:46.768 - Arduino: 0
# 00:11:46.789 - Arduino: bar: 13
# 00:11:46.805 - Arduino: lick: 8
# 00:11:46.822 - Arduino: 0
# 00:11:46.842 - Arduino: bar: 15
# 00:11:46.862 - Arduino: lick: 7
# 00:11:46.879 - Arduino: 0
# 00:11:46.899 - Arduino: bar: 14
# 00:11:46.916 - Arduino: lick: 7
# 00:11:46.932 - Arduino: 0
# 00:11:46.953 - Arduino: bar: 13
# 00:11:46.973 - Arduino: lick: 7
# 00:11:46.990 - Arduino: 0
# 00:11:47.010 - Arduino: bar: 16
# 00:11:47.026 - Arduino: lick: 7
# 00:11:47.043 - Arduino: 0
# 00:11:47.063 - Arduino: bar: 14
# 00:11:47.084 - Arduino: lick: 7
# 00:11:47.100 - Arduino: 0
# 00:11:47.120 - Arduino: bar: 14
# 00:11:47.137 - Arduino: lick: 7
# 00:11:47.153 - Arduino: 0
# 00:11:47.178 - Arduino: bar: 16
# 00:11:47.194 - Arduino: lick: 7
# 00:11:47.211 - Arduino: 0
# 00:11:47.231 - Arduino: bar: 15
# 00:11:47.248 - Arduino: lick: 7
# 00:11:47.264 - Arduino: 0
# 00:11:47.288 - Arduino: bar: 14
# 00:11:47.305 - Arduino: lick: 8
# 00:11:47.321 - Arduino: 0
# 00:11:47.342 - Arduino: bar: 17
# 00:11:47.358 - Arduino: lick: 7
# 00:11:47.378 - Arduino: 0
# 00:11:47.399 - Arduino: bar: 14
# 00:11:47.415 - Arduino: lick: 7
# 00:11:47.432 - Arduino: 0
# 00:11:47.452 - Arduino: bar: 13
# 00:11:47.473 - Arduino: lick: 8
# 00:11:47.489 - Arduino: 0
# 00:11:47.509 - Arduino: bar: 17
# 00:11:47.526 - Arduino: lick: 7
# 00:11:47.542 - Arduino: 0
# 00:11:47.563 - Arduino: bar: 15
# 00:11:47.583 - Arduino: lick: 7
# 00:11:47.600 - Arduino: 0
# 00:11:47.620 - Arduino: bar: 13
# 00:11:47.637 - Arduino: lick: 7
# 00:11:47.654 - Arduino: 0
# 00:11:47.677 - Arduino: bar: 16
# 00:11:47.694 - Arduino: lick: 7
# 00:11:47.710 - Arduino: 0
# 00:11:47.731 - Arduino: bar: 14
# 00:11:47.747 - Arduino: lick: 7
# 00:11:47.764 - Arduino: 0
# 00:11:47.788 - Arduino: bar: 13
# 00:11:47.805 - Arduino: lick: 7
# 00:11:47.821 - Arduino: 0
# 00:11:47.841 - Arduino: bar: 17
# 00:11:47.858 - Arduino: lick: 7
# 00:11:47.878 - Arduino: 0
# 00:11:47.899 - Arduino: bar: 15
# 00:11:47.915 - Arduino: lick: 7
# 00:11:47.932 - Arduino: 0
# 00:11:47.952 - Arduino: bar: 13
# 00:11:47.968 - Arduino: lick: 8
# 00:11:47.989 - Arduino: 0
# 00:11:48.009 - Arduino: bar: 16
# 00:11:48.026 - Arduino: lick: 7
# 00:11:48.042 - Arduino: 0
# 00:11:48.062 - Arduino: bar: 14
# 00:11:48.083 - Arduino: lick: 7
# 00:11:48.099 - Arduino: 0
# 00:11:48.120 - Arduino: bar: 14
# 00:11:48.136 - Arduino: lick: 7
# 00:11:48.153 - Arduino: 0
# 00:11:48.173 - Arduino: bar: 15
# 00:11:48.193 - Arduino: lick: 7
# 00:11:48.210 - Arduino: 0
# 00:11:48.230 - Arduino: bar: 14
# 00:11:48.247 - Arduino: lick: 7
# 00:11:48.263 - Arduino: 0
# 00:11:48.284 - Arduino: bar: 13
# 00:11:48.304 - Arduino: lick: 7
# 00:11:48.321 - Arduino: 0
# 00:11:48.341 - Arduino: bar: 15
# 00:11:48.358 - Arduino: lick: 8
# 00:11:48.374 - Arduino: 0
# 00:11:48.394 - Arduino: bar: 13
# 00:11:48.415 - Arduino: lick: 8
# 00:11:48.431 - Arduino: 0
# 00:11:48.451 - Arduino: bar: 13
# 00:11:48.468 - Arduino: lick: 7
# 00:11:48.484 - Arduino: 0
# 00:11:48.505 - Arduino: bar: 13
# 00:11:48.525 - Arduino: lick: 7
# 00:11:48.542 - Arduino: 0
# 00:11:48.562 - Arduino: bar: 13
# 00:11:48.579 - Arduino: lick: 8
# 00:11:48.595 - Arduino: 0
# 00:11:48.615 - Arduino: bar: 13
# 00:11:48.636 - Arduino: lick: 7
# 00:11:48.652 - Arduino: 0
# 00:11:48.673 - Arduino: bar: 14
# 00:11:48.689 - Arduino: lick: 8
# 00:11:48.706 - Arduino: 0
# 00:11:48.726 - Arduino: bar: 13
# 00:11:48.742 - Arduino: lick: 7
# 00:11:48.763 - Arduino: 0
# 00:11:48.783 - Arduino: bar: 13
# 00:11:48.800 - Arduino: lick: 7
# 00:11:48.816 - Arduino: 0
# 00:11:48.837 - Arduino: bar: 13
# 00:11:48.853 - Arduino: lick: 7
# 00:11:48.873 - Arduino: 0
# 00:11:48.939 - Arduino: bar: 22
# 00:11:48.959 - Arduino: lick: 7
# 00:11:48.976 - Arduino: 0
# 00:11:49.000 - Arduino: bar: 26
# 00:11:49.045 - Arduino: lick: 1306
# 00:11:49.062 - Arduino: 0
# 00:11:49.082 - Arduino: bar: 16
# 00:11:49.103 - Arduino: lick: 8
# 00:11:49.119 - Arduino: 0
# 00:11:49.140 - Arduino: bar: 13
# 00:11:49.156 - Arduino: lick: 8
# 00:11:49.173 - Arduino: 0
# 00:11:49.193 - Arduino: bar: 13
# 00:11:49.213 - Arduino: lick: 8
# 00:11:49.230 - Arduino: 0
# 00:11:49.250 - Arduino: bar: 13
# 00:11:49.267 - Arduino: lick: 8
# 00:11:49.283 - Arduino: 0
# 00:11:49.303 - Arduino: bar: 14
# 00:11:49.324 - Arduino: lick: 7
# 00:11:49.341 - Arduino: 0
# 00:11:49.361 - Arduino: bar: 22
# 00:11:49.381 - Arduino: lick: 8
# 00:11:49.398 - Arduino: 0
# 00:11:49.418 - Arduino: bar: 17
# 00:11:49.435 - Arduino: lick: 8
# 00:11:49.451 - Arduino: 0
# 00:11:49.475 - Arduino: bar: 18
# 00:11:49.492 - Arduino: lick: 7
# 00:11:49.512 - Arduino: 0
# 00:11:49.537 - Arduino: bar: 24
# 00:11:49.557 - Arduino: lick: 8
# 00:11:49.578 - Arduino: 0
# 00:11:49.602 - Arduino: bar: 32
# 00:11:49.639 - Arduino: lick: 8
# 00:11:49.689 - Arduino: 0
# 00:11:49.754 - Arduino: bar: 567
# 00:11:49.807 - Arduino: lick: 8
# 00:11:49.857 - Arduino: 0
# 00:11:49.922 - Arduino: bar: 555
# 00:11:49.971 - Arduino: lick: 7
# 00:11:50.024 - Arduino: 0
# 00:11:50.090 - Arduino: bar: 566
# 00:11:50.139 - Arduino: lick: 7
# 00:11:50.188 - Arduino: 0
# 00:11:50.254 - Arduino: bar: 574
# 00:11:50.307 - Arduino: lick: 7
# 00:11:50.356 - Arduino: 0
# 00:11:50.422 - Arduino: bar: 570
# 00:11:50.471 - Arduino: lick: 7
# 00:11:50.524 - Arduino: 0
# 00:11:50.590 - Arduino: bar: 574
# 00:11:50.639 - Arduino: lick: 8
# 00:11:50.675 - Arduino: 0
# 00:11:50.696 - Arduino: bar: 16
# 00:11:50.713 - Arduino: lick: 8
# 00:11:50.729 - Arduino: 0
# 00:11:50.749 - Arduino: bar: 15
# 00:11:50.770 - Arduino: lick: 7
# 00:11:50.786 - Arduino: 0
# 00:11:50.807 - Arduino: bar: 15
# 00:11:50.823 - Arduino: lick: 7
# 00:11:50.840 - Arduino: 0
# 00:11:50.860 - Arduino: bar: 14
# 00:11:50.880 - Arduino: lick: 8
# 00:11:50.897 - Arduino: 0
# 00:11:50.917 - Arduino: bar: 13
# 00:11:50.934 - Arduino: lick: 7
# 00:11:50.950 - Arduino: 0
# 00:11:50.970 - Arduino: bar: 14
# 00:11:50.991 - Arduino: lick: 7
# 00:11:51.007 - Arduino: 0
# 00:11:51.028 - Arduino: bar: 13
# 00:11:51.044 - Arduino: lick: 7
# 00:11:51.061 - Arduino: 0
# 00:11:51.081 - Arduino: bar: 13
# 00:11:51.101 - Arduino: lick: 8
# 00:11:51.118 - Arduino: 0
# 00:11:51.138 - Arduino: bar: 12
# 00:11:51.155 - Arduino: lick: 8
# 00:11:51.171 - Arduino: 0
# 00:11:51.192 - Arduino: bar: 12
# 00:11:51.212 - Arduino: lick: 7
# 00:11:51.261 - Arduino: 0
# 00:11:51.282 - Arduino: bar: 12
# 00:11:51.298 - Arduino: lick: 7
# 00:11:51.315 - Arduino: 0
# 00:11:51.335 - Arduino: bar: 13
# 00:11:51.351 - Arduino: lick: 7
# 00:11:51.372 - Arduino: 0
# 00:11:51.392 - Arduino: bar: 14
# 00:11:51.409 - Arduino: lick: 7
# 00:11:51.425 - Arduino: 0
# 00:11:51.446 - Arduino: bar: 14
# 00:11:51.462 - Arduino: lick: 7
# 00:11:51.482 - Arduino: 0
# 00:11:51.503 - Arduino: bar: 14
# 00:11:51.519 - Arduino: lick: 8
# 00:11:51.536 - Arduino: 0
# 00:11:51.556 - Arduino: bar: 14
# 00:11:51.573 - Arduino: lick: 7
# 00:11:51.593 - Arduino: 0
# 00:11:51.613 - Arduino: bar: 14
# 00:11:51.630 - Arduino: lick: 7
# 00:11:51.646 - Arduino: 0
# 00:11:51.667 - Arduino: bar: 13
# 00:11:51.683 - Arduino: lick: 8
# 00:11:51.703 - Arduino: 0
# 00:11:51.724 - Arduino: bar: 15
# 00:11:51.741 - Arduino: lick: 7
# 00:11:51.757 - Arduino: 0
# 00:11:51.777 - Arduino: bar: 14
# 00:11:51.794 - Arduino: lick: 7
# 00:11:51.814 - Arduino: 0
# 00:11:51.835 - Arduino: bar: 13
# 00:11:51.851 - Arduino: lick: 8
# 00:11:51.868 - Arduino: 0
# 00:11:51.888 - Arduino: bar: 14
# 00:11:51.904 - Arduino: lick: 8
# 00:11:51.921 - Arduino: 0
# 00:11:51.945 - Arduino: bar: 13
# 00:11:51.962 - Arduino: lick: 7
# 00:11:51.978 - Arduino: 0
# 00:11:51.998 - Arduino: bar: 13
# 00:11:52.015 - Arduino: lick: 7
# 00:11:52.031 - Arduino: 0
# 00:11:52.056 - Arduino: bar: 13
# 00:11:52.072 - Arduino: lick: 8
# 00:11:52.089 - Arduino: 0
# 00:11:52.109 - Arduino: bar: 13
# 00:11:52.126 - Arduino: lick: 7
# 00:11:52.142 - Arduino: 0
# 00:11:52.162 - Arduino: bar: 13
# 00:11:52.183 - Arduino: lick: 7
# 00:11:52.199 - Arduino: 0
# 00:11:52.220 - Arduino: bar: 12
# 00:11:52.236 - Arduino: lick: 7
# 00:11:52.253 - Arduino: 0
# 00:11:52.273 - Arduino: bar: 14
# 00:11:52.293 - Arduino: lick: 7
# 00:11:52.310 - Arduino: 0
# 00:11:52.330 - Arduino: bar: 13
# 00:11:52.347 - Arduino: lick: 7
# 00:11:52.363 - Arduino: 0
# 00:11:52.383 - Arduino: bar: 13
# 00:11:52.404 - Arduino: lick: 8
# 00:11:52.420 - Arduino: 0
# 00:11:52.441 - Arduino: bar: 15
# 00:11:52.457 - Arduino: lick: 7
# 00:11:52.474 - Arduino: 0
# 00:11:52.494 - Arduino: bar: 14
# 00:11:52.514 - Arduino: lick: 7
# 00:11:52.531 - Arduino: 0
# 00:11:52.551 - Arduino: bar: 13
# 00:11:52.568 - Arduino: lick: 8
# 00:11:52.584 - Arduino: 0
# 00:11:52.605 - Arduino: bar: 15
# 00:11:52.625 - Arduino: lick: 7
# 00:11:52.642 - Arduino: 0
# 00:11:52.662 - Arduino: bar: 12
# 00:11:52.678 - Arduino: lick: 7
# 00:11:52.695 - Arduino: 0
# 00:11:52.715 - Arduino: bar: 11
# 00:11:52.732 - Arduino: lick: 8
# 00:11:52.748 - Arduino: 0
# 00:11:52.773 - Arduino: bar: 11
# 00:11:52.789 - Arduino: lick: 7
# 00:11:52.805 - Arduino: 0
# 00:11:52.826 - Arduino: bar: 11
# 00:11:52.842 - Arduino: lick: 7
# 00:11:52.859 - Arduino: 0
# 00:11:52.879 - Arduino: bar: 11
# 00:11:52.899 - Arduino: lick: 7
# 00:11:52.916 - Arduino: 0
# 00:11:52.936 - Arduino: bar: 12
# 00:11:52.953 - Arduino: lick: 8
# 00:11:52.969 - Arduino: 0
# 00:11:52.990 - Arduino: bar: 13
# 00:11:53.006 - Arduino: lick: 7
# 00:11:53.023 - Arduino: 0
# 00:11:53.043 - Arduino: bar: 12
# 00:11:53.063 - Arduino: lick: 7
# 00:11:53.080 - Arduino: 0
# 00:11:53.100 - Arduino: bar: 10
# 00:11:53.117 - Arduino: lick: 7
# 00:11:53.133 - Arduino: 0
# 00:11:53.153 - Arduino: bar: 11
# 00:11:53.170 - Arduino: lick: 8
# 00:11:53.186 - Arduino: 0
# 00:11:53.211 - Arduino: bar: 11
# 00:11:53.227 - Arduino: lick: 7
# 00:11:53.244 - Arduino: 0
# 00:11:53.264 - Arduino: bar: 9
# 00:11:53.281 - Arduino: lick: 8
# 00:11:53.297 - Arduino: 0
# 00:11:53.317 - Arduino: bar: 8
# 00:11:53.334 - Arduino: lick: 7
# 00:11:53.350 - Arduino: 0
# 00:11:53.370 - Arduino: bar: 10
# 00:11:53.391 - Arduino: lick: 7
# 00:11:53.407 - Arduino: 0
# 00:11:53.428 - Arduino: bar: 9
# 00:11:53.444 - Arduino: lick: 8
# 00:11:53.461 - Arduino: 0
# 00:11:53.481 - Arduino: bar: 8
# 00:11:53.498 - Arduino: lick: 8
# 00:11:53.514 - Arduino: 0
# 00:11:53.534 - Arduino: bar: 8
# 00:11:53.551 - Arduino: lick: 8
# 00:11:53.567 - Arduino: 0
# 00:11:53.588 - Arduino: bar: 10
# 00:11:53.604 - Arduino: lick: 8
# 00:11:53.621 - Arduino: 0
# 00:11:53.641 - Arduino: bar: 9
# 00:11:53.657 - Arduino: lick: 8
# 00:11:53.674 - Arduino: 0
# 00:11:53.694 - Arduino: bar: 8
# 00:11:53.715 - Arduino: lick: 8
# 00:11:53.731 - Arduino: 0
# 00:11:53.751 - Arduino: bar: 9
# 00:11:53.768 - Arduino: lick: 8
# 00:11:53.784 - Arduino: 0
# 00:11:53.805 - Arduino: bar: 9
# 00:11:53.821 - Arduino: lick: 7
# 00:11:53.838 - Arduino: 0
# 00:11:53.858 - Arduino: bar: 9
# 00:11:53.874 - Arduino: lick: 7
# 00:11:53.891 - Arduino: 0
# 00:11:53.911 - Arduino: bar: 9
# 00:11:53.928 - Arduino: lick: 7
# 00:11:53.944 - Arduino: 0
# 00:11:53.964 - Arduino: bar: 8
# 00:11:53.985 - Arduino: lick: 8
# 00:11:54.001 - Arduino: 0
# 00:11:54.022 - Arduino: bar: 9
# 00:11:54.038 - Arduino: lick: 8
# 00:11:54.055 - Arduino: 0
# 00:11:54.075 - Arduino: bar: 9
# 00:11:54.092 - Arduino: lick: 7
# 00:11:54.108 - Arduino: 0
# 00:11:54.128 - Arduino: bar: 9
# 00:11:54.145 - Arduino: lick: 7
# 00:11:54.161 - Arduino: 0
# 00:11:54.181 - Arduino: bar: 9
# 00:11:54.198 - Arduino: lick: 8
# 00:11:54.214 - Arduino: 0
# 00:11:54.235 - Arduino: bar: 8
# 00:11:54.255 - Arduino: lick: 8
# 00:11:54.271 - Arduino: 0
# 00:11:54.292 - Arduino: bar: 10
# 00:11:54.308 - Arduino: lick: 7
# 00:11:54.325 - Arduino: 0
# 00:11:54.345 - Arduino: bar: 10
# 00:11:54.362 - Arduino: lick: 7
# 00:11:54.378 - Arduino: 0
# 00:11:54.399 - Arduino: bar: 8
# 00:11:54.415 - Arduino: lick: 7
# 00:11:54.432 - Arduino: 0
# 00:11:54.452 - Arduino: bar: 9
# 00:11:54.468 - Arduino: lick: 8
# 00:11:54.485 - Arduino: 0
# 00:11:54.505 - Arduino: bar: 10
# 00:11:54.522 - Arduino: lick: 7
# 00:11:54.538 - Arduino: 0
# 00:11:54.558 - Arduino: bar: 10
# 00:11:54.579 - Arduino: lick: 7
# 00:11:54.595 - Arduino: 0
# 00:11:54.616 - Arduino: bar: 8
# 00:11:54.632 - Arduino: lick: 7
# 00:11:54.649 - Arduino: 0
# 00:11:54.669 - Arduino: bar: 8
# 00:11:54.685 - Arduino: lick: 8
# 00:11:54.702 - Arduino: 0
# 00:11:54.722 - Arduino: bar: 10
# 00:11:54.739 - Arduino: lick: 7
# 00:11:54.755 - Arduino: 0
# 00:11:54.775 - Arduino: bar: 9
# 00:11:54.792 - Arduino: lick: 8
# 00:11:54.849 - Arduino: 0
# 00:11:54.874 - Arduino: bar: 10
# 00:11:54.890 - Arduino: lick: 7
# 00:11:54.907 - Arduino: 0
# 00:11:54.927 - Arduino: bar: 8
# 00:11:54.943 - Arduino: lick: 8
# 00:11:54.960 - Arduino: 0
# 00:11:54.980 - Arduino: bar: 8
# 00:11:54.997 - Arduino: lick: 8
# 00:11:55.013 - Arduino: 0
# 00:11:55.033 - Arduino: bar: 9
# 00:11:55.050 - Arduino: lick: 8
# 00:11:55.066 - Arduino: 0
# 00:11:55.087 - Arduino: bar: 10
# 00:11:55.103 - Arduino: lick: 7
# 00:11:55.120 - Arduino: 0
# 00:11:55.140 - Arduino: bar: 9
# 00:11:55.160 - Arduino: lick: 7
# 00:11:55.177 - Arduino: 0
# 00:11:55.197 - Arduino: bar: 8
# 00:11:55.214 - Arduino: lick: 8
# 00:11:55.230 - Arduino: 0
# 00:11:55.250 - Arduino: bar: 9
# 00:11:55.267 - Arduino: lick: 8
# 00:11:55.283 - Arduino: 0
# 00:11:55.304 - Arduino: bar: 9
# 00:11:55.320 - Arduino: lick: 8
# 00:11:55.337 - Arduino: 0
# 00:11:55.357 - Arduino: bar: 9
# 00:11:55.373 - Arduino: lick: 7
# 00:11:55.390 - Arduino: 0
# 00:11:55.410 - Arduino: bar: 9
# 00:11:55.427 - Arduino: lick: 7
# 00:11:55.443 - Arduino: 0
# 00:11:55.467 - Arduino: bar: 9
# 00:11:55.484 - Arduino: lick: 8
# 00:11:55.500 - Arduino: 0
# 00:11:55.521 - Arduino: bar: 9
# 00:11:55.537 - Arduino: lick: 8
# 00:11:55.554 - Arduino: 0
# 00:11:55.574 - Arduino: bar: 9
# 00:11:55.591 - Arduino: lick: 8
# 00:11:55.607 - Arduino: 0
# 00:11:55.627 - Arduino: bar: 9
# 00:11:55.644 - Arduino: lick: 7
# 00:11:55.660 - Arduino: 0
# 00:11:55.681 - Arduino: bar: 9
# 00:11:55.697 - Arduino: lick: 8
# 00:11:55.714 - Arduino: 0
# 00:11:55.734 - Arduino: bar: 8
# 00:11:55.750 - Arduino: lick: 8
# 00:11:55.771 - Arduino: 0
# 00:11:55.791 - Arduino: bar: 10
# 00:11:55.808 - Arduino: lick: 7
# 00:11:55.824 - Arduino: 0
# 00:11:55.844 - Arduino: bar: 10
# 00:11:55.861 - Arduino: lick: 7
# 00:11:55.877 - Arduino: 0
# 00:11:55.898 - Arduino: bar: 9
# 00:11:55.914 - Arduino: lick: 7
# 00:11:55.931 - Arduino: 0
# 00:11:55.951 - Arduino: bar: 9
# 00:11:55.967 - Arduino: lick: 8
# 00:11:55.984 - Arduino: 0
# 00:11:56.004 - Arduino: bar: 10
# 00:11:56.021 - Arduino: lick: 7
# 00:11:56.037 - Arduino: 0
# 00:11:56.061 - Arduino: bar: 10
# 00:11:56.078 - Arduino: lick: 7
# 00:11:56.094 - Arduino: 0
# 00:11:56.115 - Arduino: bar: 9
# 00:11:56.131 - Arduino: lick: 8
# 00:11:56.148 - Arduino: 0
# 00:11:56.168 - Arduino: bar: 9
# 00:11:56.184 - Arduino: lick: 7
# 00:11:56.201 - Arduino: 0
# 00:11:56.221 - Arduino: bar: 11
# 00:11:56.238 - Arduino: lick: 7
# 00:11:56.254 - Arduino: 0
# 00:11:56.274 - Arduino: bar: 9
# 00:11:56.291 - Arduino: lick: 7
# 00:11:56.307 - Arduino: 0
# 00:11:56.328 - Arduino: bar: 9
# 00:11:56.348 - Arduino: lick: 8
# 00:11:56.364 - Arduino: 0
# 00:11:56.385 - Arduino: bar: 9
# 00:11:56.401 - Arduino: lick: 7
# 00:11:56.418 - Arduino: 0
# 00:11:56.438 - Arduino: bar: 10
# 00:11:56.455 - Arduino: lick: 7
# 00:11:56.471 - Arduino: 0
# 00:11:56.492 - Arduino: bar: 9
# 00:11:56.508 - Arduino: lick: 7
# 00:11:56.525 - Arduino: 0
# 00:11:56.545 - Arduino: bar: 8
# 00:11:56.561 - Arduino: lick: 7
# 00:11:56.578 - Arduino: 0
# 00:11:56.598 - Arduino: bar: 9
# 00:11:56.615 - Arduino: lick: 8
# 00:11:56.635 - Arduino: 0
# 00:11:56.655 - Arduino: bar: 10
# 00:11:56.672 - Arduino: lick: 7
# 00:11:56.688 - Arduino: 0
# 00:11:56.709 - Arduino: bar: 8
# 00:11:56.725 - Arduino: lick: 8
# 00:11:56.742 - Arduino: 0
# 00:11:56.762 - Arduino: bar: 8
# 00:11:56.778 - Arduino: lick: 7
# 00:11:56.795 - Arduino: 0
# 00:11:56.815 - Arduino: bar: 8
# 00:11:56.832 - Arduino: lick: 7
# 00:11:56.848 - Arduino: 0
# 00:11:56.868 - Arduino: bar: 9
# 00:11:56.885 - Arduino: lick: 8
# 00:11:56.901 - Arduino: 0
# 00:11:56.921 - Arduino: bar: 9
# 00:11:56.942 - Arduino: lick: 8
# 00:11:56.958 - Arduino: 0
# 00:11:56.979 - Arduino: bar: 9
# 00:11:56.995 - Arduino: lick: 7
# 00:11:57.012 - Arduino: 0
# 00:11:57.032 - Arduino: bar: 8
# 00:11:57.049 - Arduino: lick: 7
# 00:11:57.065 - Arduino: 0
# 00:11:57.085 - Arduino: bar: 9
# 00:11:57.102 - Arduino: lick: 7
# 00:11:57.118 - Arduino: 0
# 00:11:57.139 - Arduino: bar: 9
# 00:11:57.155 - Arduino: lick: 7
# 00:11:57.172 - Arduino: 0
# 00:11:57.192 - Arduino: bar: 10
# 00:11:57.212 - Arduino: lick: 7
# 00:11:57.229 - Arduino: 0
# 00:11:57.249 - Arduino: bar: 8
# 00:11:57.266 - Arduino: lick: 8
# 00:11:57.282 - Arduino: 0
# 00:11:57.302 - Arduino: bar: 9
# 00:11:57.319 - Arduino: lick: 7
# 00:11:57.335 - Arduino: 0
# 00:11:57.356 - Arduino: bar: 10
# 00:11:57.372 - Arduino: lick: 7
# 00:11:57.389 - Arduino: 0
# 00:11:57.409 - Arduino: bar: 11
# 00:11:57.425 - Arduino: lick: 7
# 00:11:57.442 - Arduino: 0
# 00:11:57.462 - Arduino: bar: 9
# 00:11:57.483 - Arduino: lick: 7
# 00:11:57.499 - Arduino: 0
# 00:11:57.520 - Arduino: bar: 9
# 00:11:57.536 - Arduino: lick: 7
# 00:11:57.552 - Arduino: 0
# 00:11:57.573 - Arduino: bar: 10
# 00:11:57.589 - Arduino: lick: 8
# 00:11:57.606 - Arduino: 0
# 00:11:57.626 - Arduino: bar: 9
# 00:11:57.643 - Arduino: lick: 7
# 00:11:57.659 - Arduino: 0
# 00:11:57.679 - Arduino: bar: 8
# 00:11:57.696 - Arduino: lick: 8
# 00:11:57.712 - Arduino: 0
# 00:11:57.732 - Arduino: bar: 9
# 00:11:57.749 - Arduino: lick: 8
# 00:11:57.765 - Arduino: 0
# 00:11:57.790 - Arduino: bar: 10
# 00:11:57.806 - Arduino: lick: 8
# 00:11:57.823 - Arduino: 0
# 00:11:57.843 - Arduino: bar: 10
# 00:11:57.860 - Arduino: lick: 7
# 00:11:57.876 - Arduino: 0
# 00:11:57.896 - Arduino: bar: 8
# 00:11:57.913 - Arduino: lick: 7
# 00:11:57.929 - Arduino: 0
# 00:11:57.950 - Arduino: bar: 9
# 00:11:57.966 - Arduino: lick: 7
# 00:11:57.983 - Arduino: 0
# 00:11:58.003 - Arduino: bar: 10
# 00:11:58.023 - Arduino: lick: 7
# 00:11:58.040 - Arduino: 0
# 00:11:58.060 - Arduino: bar: 10
# 00:11:58.077 - Arduino: lick: 7
# 00:11:58.093 - Arduino: 0
# 00:11:58.113 - Arduino: bar: 8
# 00:11:58.130 - Arduino: lick: 8
# 00:11:58.147 - Arduino: 0
# 00:11:58.167 - Arduino: bar: 9
# 00:11:58.183 - Arduino: lick: 8
# 00:11:58.200 - Arduino: 0
# 00:11:58.220 - Arduino: bar: 10
# 00:11:58.237 - Arduino: lick: 8
# 00:11:58.253 - Arduino: 0
# 00:11:58.273 - Arduino: bar: 10
# 00:11:58.294 - Arduino: lick: 8
# 00:11:58.310 - Arduino: 0
# 00:11:58.331 - Arduino: bar: 8
# 00:11:58.347 - Arduino: lick: 7
# 00:11:58.363 - Arduino: 0
# 00:11:58.384 - Arduino: bar: 9
# 00:11:58.400 - Arduino: lick: 8
# 00:11:58.417 - Arduino: 0
# 00:11:58.437 - Arduino: bar: 10
# 00:11:58.458 - Arduino: lick: 7
# 00:11:58.474 - Arduino: 0
# 00:11:58.494 - Arduino: bar: 8
# 00:11:58.511 - Arduino: lick: 8
# 00:11:58.527 - Arduino: 0
# 00:11:58.548 - Arduino: bar: 8
# 00:11:58.564 - Arduino: lick: 8
# 00:11:58.584 - Arduino: 0
# 00:11:58.605 - Arduino: bar: 10
# 00:11:58.621 - Arduino: lick: 8
# 00:11:58.638 - Arduino: 0
# 00:11:58.658 - Arduino: bar: 9
# 00:11:58.675 - Arduino: lick: 7
# 00:11:58.691 - Arduino: 0
# 00:11:58.711 - Arduino: bar: 9
# 00:11:58.728 - Arduino: lick: 7
# 00:11:58.744 - Arduino: 0
# 00:11:58.765 - Arduino: bar: 9
# 00:11:58.781 - Arduino: lick: 7
# 00:11:58.798 - Arduino: 0
# ...
# 00:21:15.110 - Arduino: bar: 8
# 00:21:15.126 - Arduino: lick: 5
# 00:21:15.143 - Arduino: 0
# 00:21:15.163 - Arduino: bar: 9
# 00:21:15.180 - Arduino: lick: 5
# 00:21:15.196 - Arduino: 0
# 00:21:15.216 - Arduino: bar: 8
# 00:21:15.233 - Arduino: lick: 5
# 00:21:15.249 - Arduino: 0
# 00:21:15.270 - Arduino: bar: 8
# 00:21:15.286 - Arduino: lick: 6
# 00:21:15.303 - Arduino: 0
# 00:21:15.323 - Arduino: bar: 9
# 00:21:15.339 - Arduino: lick: 6
# 00:21:15.356 - Arduino: 0
# 00:21:15.376 - Arduino: bar: 8
# 00:21:15.393 - Arduino: lick: 4
# 00:21:15.409 - Arduino: 0
# 00:21:15.429 - Arduino: bar: 9
# 00:21:15.446 - Arduino: lick: 5
# 00:21:15.462 - Arduino: 0
# 00:21:15.483 - Arduino: bar: 8
# 00:21:15.499 - Arduino: lick: 6
# 00:21:15.516 - Arduino: 0
# 00:21:15.536 - Arduino: bar: 8
# 00:21:15.552 - Arduino: lick: 5
# 00:21:15.569 - Arduino: 0
# 00:21:15.589 - Arduino: bar: 9
# 00:21:15.606 - Arduino: lick: 6
# 00:21:15.622 - Arduino: 0
# 00:21:15.642 - Arduino: bar: 8
# 00:21:15.659 - Arduino: lick: 6
# 00:21:15.675 - Arduino: 0
# 00:21:15.696 - Arduino: bar: 9
# 00:21:15.712 - Arduino: lick: 5
# 00:21:15.729 - Arduino: 0
# 00:21:15.749 - Arduino: bar: 8
# 00:21:15.765 - Arduino: lick: 5
# 00:21:15.782 - Arduino: 0
# 00:21:15.802 - Arduino: bar: 8
# 00:21:15.819 - Arduino: lick: 5
# 00:21:15.835 - Arduino: 0
# 00:21:15.855 - Arduino: bar: 9
# 00:21:15.872 - Arduino: lick: 6
# 00:21:15.888 - Arduino: 0
# 00:21:15.909 - Arduino: bar: 8
# 00:21:15.925 - Arduino: lick: 5
# 00:21:15.942 - Arduino: 0
# 00:21:15.962 - Arduino: bar: 9
# 00:21:15.978 - Arduino: lick: 5
# 00:21:15.995 - Arduino: 0
# 00:21:16.015 - Arduino: bar: 8
# 00:21:16.032 - Arduino: lick: 5
# 00:21:16.048 - Arduino: 0
# 00:21:16.068 - Arduino: bar: 8
# 00:21:16.085 - Arduino: lick: 6
# 00:21:16.101 - Arduino: 0
# 00:21:16.122 - Arduino: bar: 9
# 00:21:16.138 - Arduino: lick: 6
# 00:21:16.155 - Arduino: 0
# 00:21:16.175 - Arduino: bar: 8
# 00:21:16.191 - Arduino: lick: 5
# 00:21:16.208 - Arduino: 0
# 00:21:16.228 - Arduino: bar: 9
# 00:21:16.245 - Arduino: lick: 5
# 00:21:16.261 - Arduino: 0
# 00:21:16.281 - Arduino: bar: 8
# 00:21:16.298 - Arduino: lick: 6
# 00:21:16.314 - Arduino: 0
# 00:21:16.335 - Arduino: bar: 8
# 00:21:16.351 - Arduino: lick: 5
# 00:21:16.368 - Arduino: 0
# 00:21:16.388 - Arduino: bar: 9
# 00:21:16.404 - Arduino: lick: 6
# 00:21:16.421 - Arduino: 0
# 00:21:16.441 - Arduino: bar: 8
# 00:21:16.458 - Arduino: lick: 5
# 00:21:16.474 - Arduino: 0
# 00:21:16.494 - Arduino: bar: 9
# 00:21:16.511 - Arduino: lick: 5
# 00:21:16.527 - Arduino: 0
# 00:21:16.548 - Arduino: bar: 8
# 00:21:16.564 - Arduino: lick: 5
# 00:21:16.580 - Arduino: 0
# 00:21:16.601 - Arduino: bar: 8
# 00:21:16.617 - Arduino: lick: 6
# 00:21:16.634 - Arduino: 0
# 00:21:16.654 - Arduino: bar: 9
# 00:21:16.671 - Arduino: lick: 6
# 00:21:16.687 - Arduino: 0
# 00:21:16.707 - Arduino: bar: 8
# 00:21:16.724 - Arduino: lick: 5
# 00:21:16.740 - Arduino: 0
# 00:21:16.761 - Arduino: bar: 9
# 00:21:16.781 - Arduino: lick: 5
# 00:21:16.794 - Arduino: 0
# 00:21:16.814 - Arduino: bar: 8
# 00:21:16.834 - Arduino: lick: 6
# 00:21:16.847 - Arduino: 0
# 00:21:16.867 - Arduino: bar: 8
# 00:21:16.887 - Arduino: lick: 5
# 00:21:16.904 - Arduino: 0
# 00:21:16.924 - Arduino: bar: 9
# 00:21:16.941 - Arduino: lick: 6
# 00:21:16.957 - Arduino: 0
# 00:21:16.978 - Arduino: bar: 8
# 00:21:16.994 - Arduino: lick: 5
# 00:21:17.010 - Arduino: 0
# 00:21:17.031 - Arduino: bar: 9
# 00:21:17.047 - Arduino: lick: 5
# 00:21:17.064 - Arduino: 0
# 00:21:17.084 - Arduino: bar: 7
# 00:21:17.100 - Arduino: lick: 5
# 00:21:17.117 - Arduino: 0
# 00:21:17.137 - Arduino: bar: 8
# 00:21:17.154 - Arduino: lick: 5
# 00:21:17.170 - Arduino: 0
# 00:21:17.191 - Arduino: bar: 8
# 00:21:17.207 - Arduino: lick: 6
# 00:21:17.223 - Arduino: 0
# 00:21:17.244 - Arduino: bar: 8
# 00:21:17.260 - Arduino: lick: 5
# 00:21:17.277 - Arduino: 0
# 00:21:17.297 - Arduino: bar: 10
# 00:21:17.314 - Arduino: lick: 5
# 00:21:17.330 - Arduino: 0
# 00:21:17.350 - Arduino: bar: 8
# 00:21:17.367 - Arduino: lick: 5
# 00:21:17.383 - Arduino: 0
# 00:21:17.404 - Arduino: bar: 8
# 00:21:17.420 - Arduino: lick: 6
# 00:21:17.436 - Arduino: 0
# 00:21:17.457 - Arduino: bar: 9
# 00:21:17.473 - Arduino: lick: 6
# 00:21:17.490 - Arduino: 0
# 00:21:17.510 - Arduino: bar: 9
# 00:21:17.527 - Arduino: lick: 5
# 00:21:17.543 - Arduino: 0
# 00:21:17.563 - Arduino: bar: 9
# 00:21:17.580 - Arduino: lick: 5
# 00:21:17.596 - Arduino: 0
# 00:21:17.617 - Arduino: bar: 8
# 00:21:17.633 - Arduino: lick: 6
# 00:21:17.649 - Arduino: 0
# 00:21:17.670 - Arduino: bar: 8
# 00:21:17.686 - Arduino: lick: 6
# 00:21:17.703 - Arduino: 0
# 00:21:17.723 - Arduino: bar: 9
# 00:21:17.740 - Arduino: lick: 6
# 00:21:17.756 - Arduino: 0
# 00:21:17.776 - Arduino: bar: 8
# 00:21:17.793 - Arduino: lick: 5
# 00:21:17.809 - Arduino: 0
# 00:21:17.830 - Arduino: bar: 9
# 00:21:17.846 - Arduino: lick: 5
# 00:21:17.862 - Arduino: 0
# 00:21:17.883 - Arduino: bar: 8
# 00:21:17.899 - Arduino: lick: 5
# 00:21:17.916 - Arduino: 0
# 00:21:17.936 - Arduino: bar: 8
# 00:21:17.953 - Arduino: lick: 5
# 00:21:17.969 - Arduino: 0
# 00:21:17.989 - Arduino: bar: 9
# 00:21:18.006 - Arduino: lick: 6
# 00:21:18.022 - Arduino: 0
# 00:21:18.043 - Arduino: bar: 8
# 00:21:18.059 - Arduino: lick: 5
# 00:21:18.075 - Arduino: 0
# 00:21:18.096 - Arduino: bar: 9
# 00:21:18.112 - Arduino: lick: 5
# 00:21:18.129 - Arduino: 0
# 00:21:18.149 - Arduino: bar: 8
# 00:21:18.165 - Arduino: lick: 5
# 00:21:18.182 - Arduino: 0
# 00:21:18.202 - Arduino: bar: 8
# 00:21:18.219 - Arduino: lick: 6
# 00:21:18.235 - Arduino: 0
# 00:21:18.256 - Arduino: bar: 9
# 00:21:18.272 - Arduino: lick: 6
# 00:21:18.288 - Arduino: 0
# 00:21:18.309 - Arduino: bar: 8
# 00:21:18.325 - Arduino: lick: 5
# 00:21:18.342 - Arduino: 0
# 00:21:18.362 - Arduino: bar: 9
# 00:21:18.378 - Arduino: lick: 5
# 00:21:18.395 - Arduino: 0
# 00:21:18.415 - Arduino: bar: 8
# 00:21:18.432 - Arduino: lick: 6
# 00:21:18.448 - Arduino: 0
# 00:21:18.469 - Arduino: bar: 8
# 00:21:18.485 - Arduino: lick: 6
# 00:21:18.501 - Arduino: 0
# 00:21:18.522 - Arduino: bar: 9
# 00:21:18.538 - Arduino: lick: 6
# 00:21:18.555 - Arduino: 0
# 00:21:18.575 - Arduino: bar: 8
# 00:21:18.591 - Arduino: lick: 5
# 00:21:18.608 - Arduino: 0
# 00:21:18.628 - Arduino: bar: 9
# 00:21:18.645 - Arduino: lick: 5
# 00:21:18.661 - Arduino: 0
# 00:21:18.681 - Arduino: bar: 8
# 00:21:18.698 - Arduino: lick: 5
# 00:21:18.714 - Arduino: 0
# 00:21:18.735 - Arduino: bar: 8
# 00:21:18.751 - Arduino: lick: 5
# 00:21:18.768 - Arduino: 0
# 00:21:18.788 - Arduino: bar: 8
# 00:21:18.804 - Arduino: lick: 6
# 00:21:18.821 - Arduino: 0
# 00:21:18.841 - Arduino: bar: 8
# 00:21:18.858 - Arduino: lick: 5
# 00:21:18.874 - Arduino: 0
# 00:21:18.894 - Arduino: bar: 9
# 00:21:18.911 - Arduino: lick: 5
# 00:21:18.927 - Arduino: 0
# 00:21:18.948 - Arduino: bar: 8
# 00:21:18.964 - Arduino: lick: 5
# 00:21:18.981 - Arduino: 0
# 00:21:19.017 - Arduino: bar: 8
# 00:21:19.050 - Arduino: lick: 5
# 00:21:19.153 - Arduino: 0
# 00:21:19.353 - Arduino: bar: 2210
# 00:21:19.526 - Arduino: lick: 5
# 00:21:19.722 - Arduino: 0
# 00:21:19.861 - Arduino: bar: 8
# 00:21:19.878 - Arduino: lick: 7
# 00:21:19.894 - Arduino: 0
# 00:21:19.914 - Arduino: bar: 7
# 00:21:19.931 - Arduino: lick: 7
# 00:21:19.947 - Arduino: 0
# 00:21:19.968 - Arduino: bar: 7
# 00:21:20.021 - Arduino: lick: 7
# 00:21:20.037 - Arduino: 0
# 00:21:20.058 - Arduino: bar: 8
# 00:21:20.078 - Arduino: lick: 7
# 00:21:20.094 - Arduino: 0
# 00:21:20.115 - Arduino: bar: 7
# 00:21:20.131 - Arduino: lick: 8
# 00:21:20.148 - Arduino: 0
# 00:21:20.168 - Arduino: bar: 8
# 00:21:20.185 - Arduino: lick: 7
# 00:21:20.201 - Arduino: 0
# 00:21:20.222 - Arduino: bar: 8
# 00:21:20.238 - Arduino: lick: 7
# 00:21:20.254 - Arduino: 0
# 00:21:20.275 - Arduino: bar: 8
# 00:21:20.291 - Arduino: lick: 7
# 00:21:20.308 - Arduino: 0
# 00:21:20.328 - Arduino: bar: 9
# 00:21:20.344 - Arduino: lick: 7
# 00:21:20.361 - Arduino: 0
# 00:21:20.381 - Arduino: bar: 8
# 00:21:20.398 - Arduino: lick: 7
# 00:21:20.414 - Arduino: 0
# 00:21:20.434 - Arduino: bar: 7
# 00:21:20.451 - Arduino: lick: 7
# 00:21:20.467 - Arduino: 0
# 00:21:20.488 - Arduino: bar: 9
# 00:21:20.508 - Arduino: lick: 7
# 00:21:20.525 - Arduino: 0
# 00:21:20.545 - Arduino: bar: 9
# 00:21:20.562 - Arduino: lick: 7
# 00:21:20.578 - Arduino: 0
# 00:21:20.598 - Arduino: bar: 7
# 00:21:20.615 - Arduino: lick: 8
# 00:21:20.631 - Arduino: 0
# 00:21:20.652 - Arduino: bar: 9
# 00:21:20.668 - Arduino: lick: 7
# 00:21:20.685 - Arduino: 0
# 00:21:20.705 - Arduino: bar: 9
# 00:21:20.721 - Arduino: lick: 8
# 00:21:20.738 - Arduino: 0
# 00:21:20.758 - Arduino: bar: 8
# 00:21:20.778 - Arduino: lick: 8
# 00:21:20.791 - Arduino: 0
# 00:21:20.987 - Arduino: bar: 3079
# 00:21:21.073 - Arduino: lick: 7
# 00:21:21.090 - Arduino: 0
# 00:21:21.110 - Arduino: bar: 8
# 00:21:21.127 - Arduino: lick: 7
# 00:21:21.143 - Arduino: 0
# 00:21:21.164 - Arduino: bar: 7
# 00:21:21.180 - Arduino: lick: 7
# 00:21:21.196 - Arduino: 0
# 00:21:21.217 - Arduino: bar: 8
# 00:21:21.233 - Arduino: lick: 7
# 00:21:21.250 - Arduino: 0
# 00:21:21.270 - Arduino: bar: 8
# 00:21:21.286 - Arduino: lick: 7
# 00:21:21.303 - Arduino: 0
# 00:21:21.336 - Arduino: bar: 8
# 00:21:21.352 - Arduino: lick: 7
# 00:21:21.368 - Arduino: 0
# 00:21:21.389 - Arduino: bar: 10
# 00:21:21.405 - Arduino: lick: 7
# 00:21:21.422 - Arduino: 0
# 00:21:21.442 - Arduino: bar: 8
# 00:21:21.458 - Arduino: lick: 7
# 00:21:21.475 - Arduino: 0
# 00:21:21.495 - Arduino: bar: 7
# 00:21:21.512 - Arduino: lick: 8
# 00:21:21.528 - Arduino: 0
# 00:21:21.549 - Arduino: bar: 8
# 00:21:21.565 - Arduino: lick: 7
# 00:21:21.581 - Arduino: 0
# 00:21:21.602 - Arduino: bar: 8
# 00:21:21.622 - Arduino: lick: 8
# 00:21:21.639 - Arduino: 0
# 00:21:21.659 - Arduino: bar: 8
# 00:21:21.676 - Arduino: lick: 7
# 00:21:21.692 - Arduino: 0
# 00:21:21.712 - Arduino: bar: 9
# 00:21:21.729 - Arduino: lick: 6
# 00:21:21.745 - Arduino: 0
# 00:21:21.766 - Arduino: bar: 8
# 00:21:21.782 - Arduino: lick: 8
# 00:21:21.799 - Arduino: 0
# 00:21:21.819 - Arduino: bar: 8
# 00:21:21.835 - Arduino: lick: 7
# 00:21:21.852 - Arduino: 0
# 00:21:21.872 - Arduino: bar: 9
# 00:21:21.889 - Arduino: lick: 7
# 00:21:21.905 - Arduino: 0
# 00:21:21.925 - Arduino: bar: 9
# 00:21:21.942 - Arduino: lick: 7
# 00:21:21.958 - Arduino: 0
# 00:21:21.979 - Arduino: bar: 8
# 00:21:21.999 - Arduino: lick: 8
# 00:21:22.015 - Arduino: 0
# 00:21:22.036 - Arduino: bar: 8
# 00:21:22.052 - Arduino: lick: 7
# 00:21:22.069 - Arduino: 0
# 00:21:22.089 - Arduino: bar: 9
# 00:21:22.106 - Arduino: lick: 7
# 00:21:22.122 - Arduino: 0
# 00:21:22.142 - Arduino: bar: 8
# 00:21:22.159 - Arduino: lick: 7
# 00:21:22.175 - Arduino: 0
# 00:21:22.196 - Arduino: bar: 8
# 00:21:22.212 - Arduino: lick: 7
# 00:21:22.229 - Arduino: 0
# 00:21:22.249 - Arduino: bar: 8
# 00:21:22.265 - Arduino: lick: 7
# 00:21:22.282 - Arduino: 0
# 00:21:22.302 - Arduino: bar: 8
# 00:21:22.319 - Arduino: lick: 7
# 00:21:22.335 - Arduino: 0
# 00:21:22.355 - Arduino: bar: 9
# 00:21:22.372 - Arduino: lick: 7
# 00:21:22.388 - Arduino: 0
# 00:21:22.409 - Arduino: bar: 9
# 00:21:22.429 - Arduino: lick: 6
# 00:21:22.445 - Arduino: 0
# 00:21:22.466 - Arduino: bar: 7
# 00:21:22.482 - Arduino: lick: 8
# 00:21:22.499 - Arduino: 0
# 00:21:22.519 - Arduino: bar: 8
# 00:21:22.536 - Arduino: lick: 8
# 00:21:22.552 - Arduino: 0
# 00:21:22.572 - Arduino: bar: 10
# 00:21:22.589 - Arduino: lick: 7
# 00:21:22.605 - Arduino: 0
# 00:21:22.626 - Arduino: bar: 8
# 00:21:22.642 - Arduino: lick: 8
# 00:21:22.659 - Arduino: 0
# 00:21:22.679 - Arduino: bar: 7
# 00:21:22.695 - Arduino: lick: 7
# 00:21:22.712 - Arduino: 0
# 00:21:22.732 - Arduino: bar: 8
# 00:21:22.749 - Arduino: lick: 8
# 00:21:22.765 - Arduino: 0
# 00:21:22.785 - Arduino: bar: 9
# 00:21:22.802 - Arduino: lick: 7
# 00:21:22.818 - Arduino: 0
# 00:21:22.839 - Arduino: bar: 8
# 00:21:22.859 - Arduino: lick: 7
# 00:21:22.875 - Arduino: 0
# 00:21:22.896 - Arduino: bar: 9
# 00:21:22.912 - Arduino: lick: 6
# 00:21:22.929 - Arduino: 0
# 00:21:22.949 - Arduino: bar: 8
# 00:21:22.966 - Arduino: lick: 8
# 00:21:22.982 - Arduino: 0
# 00:21:23.003 - Arduino: bar: 8
# 00:21:23.019 - Arduino: lick: 7
# 00:21:23.035 - Arduino: 0
# 00:21:23.056 - Arduino: bar: 10
# 00:21:23.072 - Arduino: lick: 7
# 00:21:23.089 - Arduino: 0
# 00:21:23.109 - Arduino: bar: 9
# 00:21:23.125 - Arduino: lick: 7
# 00:21:23.142 - Arduino: 0
# 00:21:23.162 - Arduino: bar: 7
# 00:21:23.179 - Arduino: lick: 7
# 00:21:23.195 - Arduino: 0
# 00:21:23.215 - Arduino: bar: 8
# 00:21:23.232 - Arduino: lick: 7
# 00:21:23.248 - Arduino: 0
# 00:21:23.269 - Arduino: bar: 9
# 00:21:23.289 - Arduino: lick: 7
# 00:21:23.306 - Arduino: 0
# 00:21:23.326 - Arduino: bar: 8
# 00:21:23.343 - Arduino: lick: 7
# 00:21:23.359 - Arduino: 0
# 00:21:23.379 - Arduino: bar: 8
# 00:21:23.396 - Arduino: lick: 7
# 00:21:23.412 - Arduino: 0
# 00:21:23.433 - Arduino: bar: 8
# 00:21:23.449 - Arduino: lick: 7
# 00:21:23.466 - Arduino: 0
# 00:21:23.486 - Arduino: bar: 8
# 00:21:23.502 - Arduino: lick: 8
# 00:21:23.519 - Arduino: 0
# 00:21:23.539 - Arduino: bar: 10
# 00:21:23.556 - Arduino: lick: 7
# 00:21:23.572 - Arduino: 0
# 00:21:23.592 - Arduino: bar: 9
# 00:21:23.609 - Arduino: lick: 7
# 00:21:23.625 - Arduino: 0
# 00:21:23.646 - Arduino: bar: 8
# 00:21:23.662 - Arduino: lick: 7
# 00:21:23.678 - Arduino: 0
# 00:21:23.699 - Arduino: bar: 8
# 00:21:23.719 - Arduino: lick: 7
# 00:21:23.736 - Arduino: 0
# 00:21:23.756 - Arduino: bar: 10
# 00:21:23.773 - Arduino: lick: 7
# 00:21:23.789 - Arduino: 0
# 00:21:23.809 - Arduino: bar: 8
# 00:21:23.826 - Arduino: lick: 8
# 00:21:23.842 - Arduino: 0
# 00:21:23.863 - Arduino: bar: 7
# 00:21:23.879 - Arduino: lick: 8
# 00:21:23.896 - Arduino: 0
# 00:21:23.916 - Arduino: bar: 8
# 00:21:23.932 - Arduino: lick: 8
# 00:21:23.949 - Arduino: 0
# 00:21:23.969 - Arduino: bar: 8
# 00:21:23.986 - Arduino: lick: 8
# 00:21:24.002 - Arduino: 0
# 00:21:24.022 - Arduino: bar: 8
# 00:21:24.039 - Arduino: lick: 7
# 00:21:24.055 - Arduino: 0
# 00:21:24.076 - Arduino: bar: 9
# 00:21:24.092 - Arduino: lick: 6
# 00:21:24.109 - Arduino: 0
# 00:21:24.129 - Arduino: bar: 8
# 00:21:24.149 - Arduino: lick: 7
# 00:21:24.166 - Arduino: 0
# 00:21:24.186 - Arduino: bar: 9
# 00:21:24.203 - Arduino: lick: 8
# 00:21:24.219 - Arduino: 0
# 00:21:24.239 - Arduino: bar: 10
# 00:21:24.256 - Arduino: lick: 7
# 00:21:24.272 - Arduino: 0
# 00:21:24.297 - Arduino: bar: 8
# 00:21:24.313 - Arduino: lick: 7
# 00:21:24.330 - Arduino: 0
# 00:21:24.350 - Arduino: bar: 8
# 00:21:24.370 - Arduino: lick: 7
# 00:21:24.387 - Arduino: 0
# 00:21:24.407 - Arduino: bar: 9
# 00:21:24.424 - Arduino: lick: 7
# 00:21:24.440 - Arduino: 0
# 00:21:24.461 - Arduino: bar: 8
# 00:21:24.477 - Arduino: lick: 7
# 00:21:24.493 - Arduino: 0
# 00:21:24.514 - Arduino: bar: 8
# 00:21:24.530 - Arduino: lick: 8
# 00:21:24.547 - Arduino: 0
# 00:21:24.567 - Arduino: bar: 8
# 00:21:24.584 - Arduino: lick: 8
# 00:21:24.600 - Arduino: 0
# 00:21:24.641 - Arduino: bar: 8
# 00:21:24.657 - Arduino: lick: 8
# 00:21:24.674 - Arduino: 0
# 00:21:24.694 - Arduino: bar: 8
# 00:21:24.710 - Arduino: lick: 7
# 00:21:24.727 - Arduino: 0
# 00:21:24.747 - Arduino: bar: 8
# 00:21:24.764 - Arduino: lick: 7
# 00:21:24.780 - Arduino: 0
# 00:21:24.801 - Arduino: bar: 8
# 00:21:24.817 - Arduino: lick: 8
# 00:21:24.834 - Arduino: 0
# 00:21:24.854 - Arduino: bar: 10
# 00:21:24.870 - Arduino: lick: 7
# 00:21:24.887 - Arduino: 0
# 00:21:24.907 - Arduino: bar: 8
# 00:21:24.928 - Arduino: lick: 7
# 00:21:24.944 - Arduino: 0
# 00:21:24.964 - Arduino: bar: 7
# 00:21:24.981 - Arduino: lick: 7
# 00:21:24.997 - Arduino: 0
# 00:21:25.018 - Arduino: bar: 7
# 00:21:25.034 - Arduino: lick: 7
# 00:21:25.051 - Arduino: 0
# 00:21:25.071 - Arduino: bar: 9
# 00:21:25.087 - Arduino: lick: 7
# 00:21:25.104 - Arduino: 0
# 00:21:25.124 - Arduino: bar: 8
# 00:21:25.141 - Arduino: lick: 7
# 00:21:25.157 - Arduino: 0
# 00:21:25.177 - Arduino: bar: 7
# 00:21:25.194 - Arduino: lick: 7
# 00:21:25.210 - Arduino: 0
# 00:21:25.231 - Arduino: bar: 8
# 00:21:25.247 - Arduino: lick: 7
# 00:21:25.264 - Arduino: 0
# 00:21:25.284 - Arduino: bar: 8
# 00:21:25.300 - Arduino: lick: 8
# 00:21:25.317 - Arduino: 0
# 00:21:25.337 - Arduino: bar: 9
# 00:21:25.358 - Arduino: lick: 7
# 00:21:25.374 - Arduino: 0
# 00:21:25.394 - Arduino: bar: 9
# 00:21:25.411 - Arduino: lick: 7
# 00:21:25.427 - Arduino: 0
# 00:21:25.448 - Arduino: bar: 8
# 00:21:25.464 - Arduino: lick: 8
# 00:21:25.481 - Arduino: 0
# 00:21:25.501 - Arduino: bar: 8
# 00:21:25.517 - Arduino: lick: 7
# 00:21:25.534 - Arduino: 0
# 00:21:25.554 - Arduino: bar: 9
# 00:21:25.571 - Arduino: lick: 7
# 00:21:25.587 - Arduino: 0
# 00:21:25.607 - Arduino: bar: 7
# 00:21:25.624 - Arduino: lick: 7
# 00:21:25.640 - Arduino: 0
# 00:21:25.661 - Arduino: bar: 7
# 00:21:25.677 - Arduino: lick: 7
# 00:21:25.694 - Arduino: 0
# 00:21:25.714 - Arduino: bar: 8
# 00:21:25.730 - Arduino: lick: 8
# 00:21:25.747 - Arduino: 0
# Sent stop command to Arduino.

# %%
# skip 
def get_integer_input(prompt):
    while True:
        try:
            value = int(input(prompt))
            return value
        except ValueError:
            print("Invalid input. Please enter a valid integer.")

# %%
# skip only run if you want to redefine the touch duration
set_touch = get_integer_input("Enter touch duration in msec: ")
# Out:
# Enter touch duration in msec:  1500

# %%
#skip only run if you want to redefine the solenoid open duration
set_sol = get_integer_input("Enter solenoid open duration in msec: ")
# Out:
# Enter solenoid open duration in msec:  25

# %%
#skip depricated version where we try to send variable values to arduino
port = '/dev/tty.usbmodem101'  # Replace with your Arduino's port
baudrate = 115200  # make sure this matches the baud rate in the Arduino sketch (.ino file)
run_time = 30 #sec
#request user for identiying information
animal_ID = input("Enter Animal ID: ")
training_stage = input("Enter training stage: ")

#open window to choose directory 
root = Tk()
root.withdraw()  # Hide the main tkinter window
save_directory = askdirectory(title="Select Directory to Save Data File")
data_filename = f"{animal_ID}_{training_stage}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
data_filepath = os.path.join(save_directory, data_filename)

#initialize text file to write to as 'file'
with open(data_filepath, 'w') as file:
    #initialize serial connection
    ser = serial.Serial(port, baudrate, timeout=1)
    time.sleep(2) 
    
    #update arrduino variables if redefined by user
    if set_touch:
        ser.write(f"SET_TOUCH={set_touch}\n".encode('utf-8'))
        time.sleep(1)  
        print(f"Touch duration set to: {set_touch} msec")
        file.write(f"Touch duration set to: {set_touch} msec\n")
    if set_sol:
        ser.write(f"SET_SOL={set_sol}\n".encode('utf-8'))
        time.sleep(1)  
        print(f"Solenoid open duration set to: {set_sol} msec")
        file.write(f"Solenoid open duration set to: {set_sol} msec\n")
    
    #TRIGGER CAMERA, 2P HERE
    
    #send start command to Arduino
    start_time = time.time() #use for duration based arduino script start/stop
    ser.write("S\n".encode('utf-8')) #ser.write(b'S') char version not compatible with string arduino readout
    behav_active = True
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
    print(f'{timestamp} - Sent start command to Arduino.')
    file.write(f'{timestamp} - Sent start command to Arduino.\n')
    
    try:
        # Read data from Arduino
        while behav_active:
            if ser.in_waiting > 0:
                try:
                    line = ser.readline().decode('utf-8', errors='ignore').rstrip()
                    timestamp = datetime.now().strftime('%H:%M:%S.%f')[:-3]
                    log_line = f'{timestamp} - Arduino: {line}\n'
                    print(log_line, end='')  # Print the data in real-time
                    file.write(log_line)  # Save data to file incrementally
                    file.flush()  # Ensure the data is written to the disk
                    os.fsync(file.fileno())  # Force writing to disk
                except UnicodeDecodeError:
                    print("Failed to decode serial data")
                    continue
    
            # Check if 20 seconds have passed to send the stop command
            if time.time() - start_time >= run_time:
                #execution line (send stop command to arduino)
                ser.write("X\n".encode('utf-8')) #ser.write(b'X') char version not compatible with string arduino readout
                #reporting lines
                print('Sent stop command to Arduino.')
                timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
                file.write(f'{timestamp} - Sent stop command to Arduino.')
                #exit behavior code line
                behav_active = False
    
    except KeyboardInterrupt:
        #execution line (send stop command to arduino)
        ser.write("X\n".encode('utf-8')) #ser.write(b'X') char version not compatible with string arduino readout
        #reporting lines
        print("Interrupted by user. Sent stop command to Arduino.")
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
        file.write(f'{timestamp} - Interrupted by user. Sent stop command to Arduino.')
    finally:
        #close serial connection
        ser.close()
# Out:
# Enter Animal ID:  test
# Enter training stage:  lick
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 23
#      20 time.sleep(2)
#      22 #update arrduino variables if redefined by user
# ---> 23 if set_touch:
#      24     ser.write(f"SET_TOUCH={set_touch}\n".encode('utf-8'))
#      25     time.sleep(1)
#
# NameError: name 'set_touch' is not defined

# %%
#depricated version where we save data to csv at end. 
#not worth bc postprocessing will be much better and this has no intermittent save data  
port = '/dev/tty.usbmodem101'  # Replace with your Arduino's port
baudrate = 115200  # make sure this matches the baud rate in the Arduino sketch (.ino file)
#request user for identiying information
#in the future commands sent to arduino can be changed based on the training stage 
animal_ID = input("Enter Animal ID: ")
training_stage = input("Enter training stage: ")

#initialize serial connection
ser = serial.Serial(port, baudrate, timeout=1)
time.sleep(2)  # wait for the connection to be established
#TRIGGER CAMERA, 2P HERE
#initialize list for sensor data storage 
sensor_data = []

#send start command to Arduino
start_time = time.time() #use for duration based arduino script start/stop
ser.write(b'S') 
behav_active = True
timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
print(f'{timestamp} - Sent start command to Arduino.')

try:
    # Read data from Arduino
    while behav_active:
        if ser.in_waiting > 0:
            try:
                line = ser.readline().decode('utf-8', errors='ignore').rstrip()
                timestamp = datetime.now().strftime('%H:%M:%S.%f')[:-3]
                print(f'{timestamp} - Arduino: {line}')
                sensor_data.append([timestamp, line])
            except UnicodeDecodeError:
                print("Failed to decode serial data")
                continue

        # Check if 20 seconds have passed to send the stop command
        if time.time() - start_time >= 20:
            ser.write(b'X')
            print('Sent stop command to Arduino.')
            behav_active = False

except KeyboardInterrupt:
    ser.write(b'X')
    print("Interrupted by user. Sent stop command to Arduino.")
finally:
    # Open a dialog to choose a directory to save the CSV file
    root = Tk()
    root.withdraw()  # Hide the main tkinter window
    save_directory = askdirectory(title="Select Directory to Save CSV File")

    if save_directory:  # Check if the user selected a directory
        csv_filename = f"{animal_ID}_{training_stage}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        csv_filepath = os.path.join(save_directory, csv_filename)

        # Save sensor data to CSV
        with open(csv_filepath, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["Timestamp", "Sensor Data"])
            writer.writerows(sensor_data)
        print(f"Sensor data saved to {csv_filepath}")
    else:
        print("No directory selected. Data not saved.")
    #close serial connection
    ser.close()

# %% [markdown]
# I have decided that keeping code inside a main script is totally irrelvant in jupyter notebook
# so I will instead just put the behavior triggering code within the cell directly.

# %%
def main():
    animal_id = input("Enter Animal ID: ")
    session_type = input("Enter Session Type: ")

if __name__ == '__main__':
    main()
# Out:
# Enter Animal ID:  animal1
# Enter Session Type:  lick_direct

# %%
animal_id = input("Enter Animal ID: ")
session_type = input("Enter Session Type: ")
# Out:
# Enter Animal ID:  animal1
# Enter Session Type:  lick

# %%
#old version, keep for history 
def main():
    port = '/dev/tty.usbmodem101'  # Replace with your Arduino's port
    baudrate = 115200
    solenoidCount = 0
    # Initialize serial connection
    ser = serial.Serial(port, baudrate, timeout=1)
    time.sleep(2)  # Wait for the connection to be established

    # Send start command to Arduino
    ser.write(b'S')
    print('Sent start command to Arduino.')

    try:
        # Read data from Arduino
        while True:
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').rstrip()
                print(f'Arduino: {line}')
                if line == 'Solenoid Activated':
                    solenoidCount+=1
                if solenoidCount >10:
                    break  # Exit loop after solenoid activation (modify as needed)

            # Check for stop condition or other conditions as needed
            # e.g., send stop command 'X' to Arduino
            # ser.write(b'X')
            # break
    except KeyboardInterrupt:
        print("Interrupted by user")
        ser.write(b'X')  # Send stop command to Arduino
    finally:
        # Close serial connection
        ser.close()

# Ensure the main function is called if this script is executed directly
if __name__ == '__main__':
    main()

# %%
#old calibration script, for fixed arduino script. 
#need to ensure arduino has the correct ino file uploaded. #calibrate_open_solenoid.ino
port = '/dev/tty.usbmodem101'  # Replace with your Arduino's port
baudrate = 115200
drops = 10

# Initialize serial connection
ser = serial.Serial(port, baudrate, timeout=1)
time.sleep(2)  # Wait for the connection to be established

for i in range(drops):
    ser.write(b'C')
    print(f'valve open / drop {i+1}')
    time.sleep(0.1)  # Short delay to allow the Arduino to respond
    if ser.in_waiting > 0:
        response = ser.readline().decode('utf-8').rstrip()
        print(f'Arduino: {response}')
    
    # Optional: Additional delay between drops
    time.sleep(1)
# Close serial connection
ser.close()
# Out:
# valve open / drop 1
# Arduino: Solenoid Activated
# valve open / drop 2
# Arduino: Sol pin status: 1
# valve open / drop 3
# Arduino: Sol pin status: 1
# valve open / drop 4
# Arduino: Solenoid Activated
# valve open / drop 5
# Arduino: Sol pin status: 1
# valve open / drop 6
# Arduino: Sol pin status: 1
# valve open / drop 7
# Arduino: Solenoid Activated
# valve open / drop 8
# Arduino: Sol pin status: 1
# valve open / drop 9
# Arduino: Sol pin status: 1
# valve open / drop 10
# Arduino: Solenoid Activated
